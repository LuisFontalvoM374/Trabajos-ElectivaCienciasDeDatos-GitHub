# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisFontalvoM374/Trabajos-ElectivaCienciasDeDatos-GitHub/blob/main/db_SQLite_inventario1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gestión Básica de Inventario con SQLite3

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# sqlite3 is already the newest version (3.37.2-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQLite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Nombre de la tabla a eliminar/crear
inventario = 'inventario'

# Eliminar la tabla si existe
c.execute(f"DROP TABLE IF EXISTS {inventario}")

# Crear una nueva tabla llamada 'inventario'
c.execute('''CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)''')

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.commit()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# (5001, 'Objeto5001', 'Hogar', 312.15, 51, 'Proveedor2', '2023-08-11', 'Almacén A')
# (5002, 'Artículo5002', 'Jardín', 438.24, 71, 'Proveedor1', '2023-08-14', 'Almacén A')
# (5003, 'Artículo5003', 'Electrónica', 326.23, 79, 'Proveedor1', '2023-08-14', 'Almacén B')
# (5004, 'Producto5004', 'Moda', 35.95, 20, 'Proveedor3', '2023-08-26', 'Almacén C')
# (5005, 'Producto5005', 'Moda', 44.19, 66, 'Proveedor3', '2023-09-09', 'Almacén A')
# (5006, 'Objeto5006', 'Jardín', 354.59, 5, 'Proveedor1', '2023-01-20', 'Almacén A')
# (5007, 'Artículo5007', 'Moda', 290.31, 81, 'Proveedor2', '2023-03-08', 'Almacén B')
# (5008, 'Artículo5008', 'Hogar', 247.8, 79, 'Proveedor2', '2023-11-06', 'Almacén C')
# (5009, 'Artículo5009', 'Deportes', 51.26, 24, 'Proveedor2', '2023-07-22', 'Almacén B')
# (5010, 'Producto5010', 'Electrónica', 72.52, 21, 'Proveedor1', '2023-05-15', 'Almacén B')
# (5011, 'Artículo5011', 'Jardín', 464.33, 33, 'Proveedor3', '2023-02-26', 'Almacén A')
# (5012, 'Objeto5012', 'Electrónica', 129.56, 99, 'Proveedor2', '2023-06-20', 'Almacén A')
# (5013, 'Objeto5013', 'Hogar', 110.89, 82, 'Proveedor2', '2023-02-25', 'Almacén B')
# (5014, 'Artículo5014', 'Moda', 299.51, 19, 'Proveedor1', '2023-04-16', 'Almacén B')
# (5015, 'Objeto5015', 'Deportes', 331.54, 87, 'Proveedor2', '2023-01-15', 'Almacén A')
# (5016, 'Producto5016', 'Hogar', 157.73, 67, 'Proveedor3', '2023-07-06', 'Almacén A')
# (5017, 'Producto5017', 'Electrónica', 72.6, 86, 'Proveedor1', '2023-04-15', 'Almacén B')
# (5018, 'Objeto5018', 'Jardín', 233.1, 17, 'Proveedor1', '2023-01-28', 'Almacén B')
# (5019, 'Producto5019', 'Electrónica', 379.64, 28, 'Proveedor1', '2023-01-07', 'Almacén B')
# (5020, 'Producto5020', 'Hogar', 95.36, 85, 'Proveedor2', '2023-03-24', 'Almacén C')
# (5021, 'Artículo5021', 'Moda', 450.67, 8, 'Proveedor1', '2023-10-27', 'Almacén C')
# (5022, 'Artículo5022', 'Electrónica', 432.56, 57, 'Proveedor2', '2023-03-21', 'Almacén A')
# (5023, 'Objeto5023', 'Electrónica', 475.39, 71, 'Proveedor3', '2023-01-03', 'Almacén A')
# (5024, 'Producto5024', 'Hogar', 497.6, 68, 'Proveedor2', '2023-07-17', 'Almacén C')
# (5025, 'Producto5025', 'Jardín', 243.99, 43, 'Proveedor2', '2023-04-14', 'Almacén C')
# (5026, 'Producto5026', 'Electrónica', 370.63, 29, 'Proveedor3', '2023-10-09', 'Almacén A')
# (5027, 'Producto5027', 'Electrónica', 10.16, 43, 'Proveedor3', '2023-10-04', 'Almacén A')
# (5028, 'Producto5028', 'Moda', 435.52, 97, 'Proveedor2', '2023-04-07', 'Almacén C')
# (5029, 'Objeto5029', 'Jardín', 117.54, 28, 'Proveedor1', '2023-08-11', 'Almacén C')
# (5030, 'Artículo5030', 'Jardín', 351.22, 76, 'Proveedor2', '2023-11-03', 'Almacén C')
# (5031, 'Objeto5031', 'Deportes', 443.52, 82, 'Proveedor2', '2023-09-28', 'Almacén B')
# (5032, 'Producto5032', 'Electrónica', 231.96, 94, 'Proveedor1', '2023-08-27', 'Almacén B')
# (5033, 'Producto5033', 'Hogar', 207.52, 69, 'Proveedor3', '2023-01-01', 'Almacén B')
# (5034, 'Producto5034', 'Electrónica', 123.34, 47, 'Proveedor2', '2023-07-17', 'Almacén C')
# (5035, 'Objeto5035', 'Hogar', 24.2, 20, 'Proveedor1', '2023-07-07', 'Almacén A')
# (5036, 'Producto5036', 'Deportes', 323.85, 95, 'Proveedor3', '2023-03-17', 'Almacén A')
# (5037, 'Objeto5037', 'Moda', 74.89, 70, 'Proveedor1', '2023-04-28', 'Almacén B')
# (5038, 'Artículo5038', 'Electrónica', 272.8, 75, 'Proveedor2', '2023-01-05', 'Almacén B')
# (5039, 'Objeto5039', 'Deportes', 85.12, 37, 'Proveedor1', '2023-06-11', 'Almacén A')
# (5040, 'Producto5040', 'Electrónica', 150.32, 16, 'Proveedor1', '2023-01-19', 'Almacén B')
# (5041, 'Producto5041', 'Deportes', 319.58, 16, 'Proveedor2', '2023-05-01', 'Almacén A')
# (5042, 'Objeto5042', 'Deportes', 494.48, 69, 'Proveedor3', '2023-07-22', 'Almacén B')
# (5043, 'Producto5043', 'Hogar', 65.67, 34, 'Proveedor2', '2023-04-20', 'Almacén A')
# (5044, 'Artículo5044', 'Deportes', 276.3, 52, 'Proveedor1', '2023-02-26', 'Almacén A')
# (5045, 'Producto5045', 'Hogar', 388.9, 87, 'Proveedor3', '2023-12-18', 'Almacén B')
# (5046, 'Artículo5046', 'Hogar', 426.33, 95, 'Proveedor2', '2023-08-18', 'Almacén A')
# (5047, 'Objeto5047', 'Electrónica', 304.39, 91, 'Proveedor1', '2023-09-06', 'Almacén A')
# (5048, 'Artículo5048', 'Deportes', 127.17, 66, 'Proveedor3', '2023-05-25', 'Almacén C')
# (5049, 'Objeto5049', 'Electrónica', 224.67, 33, 'Proveedor2', '2023-10-26', 'Almacén B')
# (5050, 'Producto5050', 'Jardín', 181.86, 37, 'Proveedor3', '2023-03-10', 'Almacén A')
# (5051, 'Producto5051', 'Jardín', 82.16, 22, 'Proveedor1', '2023-04-25', 'Almacén B')
# (5052, 'Artículo5052', 'Jardín', 289.02, 29, 'Proveedor3', '2023-04-04', 'Almacén B')
# (5053, 'Producto5053', 'Deportes', 60.73, 69, 'Proveedor3', '2023-08-19', 'Almacén B')
# (5054, 'Producto5054', 'Hogar', 88.3, 93, 'Proveedor2', '2023-02-12', 'Almacén A')
# (5055, 'Artículo5055', 'Jardín', 343.33, 100, 'Proveedor1', '2023-11-21', 'Almacén C')
# (5056, 'Objeto5056', 'Moda', 15.31, 40, 'Proveedor2', '2023-08-18', 'Almacén B')
# (5057, 'Artículo5057', 'Deportes', 247.05, 83, 'Proveedor2', '2023-02-26', 'Almacén B')
# (5058, 'Objeto5058', 'Moda', 402.74, 74, 'Proveedor3', '2023-12-10', 'Almacén C')
# (5059, 'Objeto5059', 'Hogar', 373.65, 50, 'Proveedor1', '2023-08-18', 'Almacén A')
# (5060, 'Artículo5060', 'Moda', 188.95, 92, 'Proveedor1', '2023-02-24', 'Almacén B')
# (5061, 'Objeto5061', 'Electrónica', 445.9, 7, 'Proveedor2', '2023-07-22', 'Almacén A')
# (5062, 'Producto5062', 'Hogar', 152.95, 56, 'Proveedor3', '2023-02-09', 'Almacén B')
# (5063, 'Objeto5063', 'Deportes', 420.64, 87, 'Proveedor2', '2023-01-04', 'Almacén A')
# (5064, 'Producto5064', 'Electrónica', 135.29, 54, 'Proveedor3', '2023-12-11', 'Almacén A')
# (5065, 'Artículo5065', 'Electrónica', 316, 46, 'Proveedor3', '2023-11-17', 'Almacén A')
# (5066, 'Producto5066', 'Moda', 100.63, 74, 'Proveedor3', '2023-09-23', 'Almacén A')
# (5067, 'Objeto5067', 'Hogar', 346.22, 70, 'Proveedor1', '2023-02-03', 'Almacén A')
# (5068, 'Objeto5068', 'Deportes', 409.3, 13, 'Proveedor3', '2023-04-06', 'Almacén C')
# (5069, 'Producto5069', 'Deportes', 396.05, 42, 'Proveedor3', '2023-08-11', 'Almacén B')
# (5070, 'Artículo5070', 'Electrónica', 87.42, 91, 'Proveedor2', '2023-06-10', 'Almacén A')
# (5071, 'Producto5071', 'Hogar', 455.88, 18, 'Proveedor3', '2023-04-01', 'Almacén A')
# (5072, 'Objeto5072', 'Deportes', 142.65, 21, 'Proveedor1', '2023-01-05', 'Almacén A')
# (5073, 'Objeto5073', 'Hogar', 138.12, 65, 'Proveedor3', '2023-12-11', 'Almacén C')
# (5074, 'Objeto5074', 'Hogar', 476.35, 25, 'Proveedor1', '2023-11-25', 'Almacén B')
# (5075, 'Artículo5075', 'Hogar', 404.42, 94, 'Proveedor2', '2023-07-26', 'Almacén C')
# (5076, 'Artículo5076', 'Deportes', 371.59, 94, 'Proveedor3', '2023-04-25', 'Almacén C')
# (5077, 'Producto5077', 'Hogar', 357.7, 27, 'Proveedor1', '2023-09-06', 'Almacén B')
# (5078, 'Producto5078', 'Hogar', 75.67, 2, 'Proveedor1', '2023-02-26', 'Almacén C')
# (5079, 'Artículo5079', 'Moda', 232.44, 53, 'Proveedor3', '2023-12-09', 'Almacén C')
# (5080, 'Objeto5080', 'Jardín', 101.67, 46, 'Proveedor2', '2023-07-22', 'Almacén B')
# (5081, 'Artículo5081', 'Jardín', 16.41, 38, 'Proveedor2', '2023-01-06', 'Almacén B')
# (5082, 'Producto5082', 'Hogar', 154.94, 95, 'Proveedor3', '2023-04-04', 'Almacén B')
# (5083, 'Artículo5083', 'Deportes', 116.78, 9, 'Proveedor3', '2023-09-07', 'Almacén C')
# (5084, 'Objeto5084', 'Moda', 21.12, 88, 'Proveedor2', '2023-12-05', 'Almacén A')
# (5085, 'Producto5085', 'Jardín', 225.05, 95, 'Proveedor2', '2023-06-02', 'Almacén C')
# (5086, 'Artículo5086', 'Electrónica', 226.92, 42, 'Proveedor1', '2023-08-23', 'Almacén B')
# (5087, 'Artículo5087', 'Jardín', 46.61, 90, 'Proveedor3', '2023-03-14', 'Almacén B')
# (5088, 'Artículo5088', 'Deportes', 434.87, 9, 'Proveedor1', '2023-04-14', 'Almacén C')
# (5089, 'Objeto5089', 'Jardín', 419.48, 44, 'Proveedor2', '2023-11-20', 'Almacén C')
# (5090, 'Artículo5090', 'Deportes', 52.61, 96, 'Proveedor3', '2023-04-23', 'Almacén B')
# (5091, 'Producto5091', 'Electrónica', 30.54, 11, 'Proveedor1', '2023-10-15', 'Almacén C')
# (5092, 'Objeto5092', 'Hogar', 72.63, 85, 'Proveedor2', '2023-03-18', 'Almacén B')
# (5093, 'Artículo5093', 'Electrónica', 281.01, 84, 'Proveedor3', '2023-05-05', 'Almacén A')
# (5094, 'Objeto5094', 'Hogar', 302.98, 89, 'Proveedor2', '2023-02-15', 'Almacén B')
# (5095, 'Artículo5095', 'Deportes', 315.06, 69, 'Proveedor2', '2023-10-10', 'Almacén B')
# (5096, 'Artículo5096', 'Electrónica', 409.53, 2, 'Proveedor3', '2023-06-01', 'Almacén A')
# (5097, 'Producto5097', 'Deportes', 262.26, 75, 'Proveedor1', '2023-04-01', 'Almacén C')
# (5098, 'Objeto5098', 'Jardín', 134.44, 81, 'Proveedor3', '2023-08-17', 'Almacén C')
# (5099, 'Producto5099', 'Deportes', 433.06, 48, 'Proveedor2', '2023-09-17', 'Almacén C')
# (5100, 'Artículo5100', 'Jardín', 91.02, 16, 'Proveedor1', '2023-02-23', 'Almacén A')
# (5101, 'Objeto5101', 'Electrónica', 279.16, 62, 'Proveedor3', '2023-09-04', 'Almacén A')
# (5102, 'Objeto5102', 'Electrónica', 25.96, 55, 'Proveedor2', '2023-11-08', 'Almacén B')
# (5103, 'Artículo5103', 'Hogar', 479.19, 55, 'Proveedor3', '2023-03-26', 'Almacén C')
# (5104, 'Artículo5104', 'Electrónica', 455.26, 11, 'Proveedor2', '2023-04-16', 'Almacén A')
# (5105, 'Artículo5105', 'Jardín', 10.1, 30, 'Proveedor3', '2023-08-23', 'Almacén B')
# (5106, 'Producto5106', 'Electrónica', 32.19, 96, 'Proveedor2', '2023-06-21', 'Almacén A')
# (5107, 'Artículo5107', 'Moda', 411.17, 91, 'Proveedor3', '2023-02-17', 'Almacén B')
# (5108, 'Artículo5108', 'Electrónica', 485.52, 15, 'Proveedor3', '2023-01-01', 'Almacén C')
# (5109, 'Artículo5109', 'Electrónica', 300.56, 45, 'Proveedor2', '2023-07-17', 'Almacén C')
# (5110, 'Objeto5110', 'Hogar', 149.54, 65, 'Proveedor3', '2023-01-01', 'Almacén A')
# (5111, 'Artículo5111', 'Electrónica', 364.84, 83, 'Proveedor2', '2023-02-27', 'Almacén A')
# (5112, 'Producto5112', 'Electrónica', 45.47, 79, 'Proveedor1', '2023-07-11', 'Almacén B')
# (5113, 'Producto5113', 'Jardín', 168.86, 18, 'Proveedor3', '2023-11-17', 'Almacén C')
# (5114, 'Objeto5114', 'Electrónica', 363.12, 79, 'Proveedor1', '2023-12-25', 'Almacén B')
# (5115, 'Producto5115', 'Electrónica', 322.72, 44, 'Proveedor2', '2023-03-01', 'Almacén C')
# (5116, 'Artículo5116', 'Moda', 88.02, 22, 'Proveedor1', '2023-12-01', 'Almacén B')
# (5117, 'Producto5117', 'Moda', 481.88, 4, 'Proveedor1', '2023-03-25', 'Almacén C')
# (5118, 'Objeto5118', 'Moda', 186.39, 70, 'Proveedor3', '2023-08-16', 'Almacén A')
# (5119, 'Producto5119', 'Electrónica', 251.88, 73, 'Proveedor3', '2023-06-22', 'Almacén B')
# (5120, 'Artículo5120', 'Deportes', 192.01, 6, 'Proveedor1', '2023-05-12', 'Almacén B')
# (5121, 'Objeto5121', 'Hogar', 365.94, 11, 'Proveedor3', '2023-11-22', 'Almacén C')
# (5122, 'Objeto5122', 'Deportes', 26.22, 42, 'Proveedor1', '2023-05-16', 'Almacén C')
# (5123, 'Artículo5123', 'Deportes', 56.88, 94, 'Proveedor2', '2023-08-15', 'Almacén C')
# (5124, 'Artículo5124', 'Deportes', 37.48, 20, 'Proveedor3', '2023-03-04', 'Almacén A')
# (5125, 'Producto5125', 'Jardín', 304.16, 36, 'Proveedor2', '2023-07-11', 'Almacén B')
# (5126, 'Objeto5126', 'Deportes', 158.76, 33, 'Proveedor3', '2023-07-01', 'Almacén B')
# (5127, 'Artículo5127', 'Hogar', 297.98, 76, 'Proveedor1', '2023-09-01', 'Almacén A')
# (5128, 'Producto5128', 'Hogar', 449.02, 62, 'Proveedor3', '2023-05-01', 'Almacén C')
# (5129, 'Artículo5129', 'Jardín', 146.35, 87, 'Proveedor3', '2023-11-08', 'Almacén C')
# (5130, 'Objeto5130', 'Deportes', 253.97, 47, 'Proveedor3', '2023-07-19', 'Almacén B')
# (5131, 'Objeto5131', 'Electrónica', 392.67, 72, 'Proveedor1', '2023-10-10', 'Almacén C')
# (5132, 'Objeto5132', 'Jardín', 469.13, 61, 'Proveedor2', '2023-07-23', 'Almacén C')
# (5133, 'Objeto5133', 'Electrónica', 100.19, 49, 'Proveedor3', '2023-07-24', 'Almacén A')
# (5134, 'Producto5134', 'Electrónica', 24.6, 74, 'Proveedor2', '2023-02-27', 'Almacén C')
# (5135, 'Objeto5135', 'Electrónica', 210.22, 71, 'Proveedor1', '2023-04-25', 'Almacén A')
# (5136, 'Artículo5136', 'Electrónica', 134.69, 96, 'Proveedor1', '2023-06-01', 'Almacén C')
# (5137, 'Producto5137', 'Electrónica', 172.52, 97, 'Proveedor2', '2023-03-04', 'Almacén B')
# (5138, 'Producto5138', 'Electrónica', 418.5, 61, 'Proveedor1', '2023-03-06', 'Almacén A')
# (5139, 'Objeto5139', 'Electrónica', 226.83, 62, 'Proveedor3', '2023-05-08', 'Almacén A')
# (5140, 'Objeto5140', 'Moda', 377.42, 82, 'Proveedor2', '2023-01-10', 'Almacén A')
# (5141, 'Objeto5141', 'Jardín', 80.88, 58, 'Proveedor2', '2023-08-26', 'Almacén A')
# (5142, 'Objeto5142', 'Electrónica', 405.9, 19, 'Proveedor2', '2023-12-01', 'Almacén B')
# (5143, 'Objeto5143', 'Electrónica', 306.01, 84, 'Proveedor1', '2023-05-18', 'Almacén B')
# (5144, 'Producto5144', 'Jardín', 206.09, 12, 'Proveedor2', '2023-01-26', 'Almacén A')
# (5145, 'Producto5145', 'Deportes', 193.49, 76, 'Proveedor3', '2023-08-17', 'Almacén A')
# (5146, 'Objeto5146', 'Moda', 397.72, 57, 'Proveedor1', '2023-03-16', 'Almacén A')
# (5147, 'Producto5147', 'Hogar', 36.78, 10, 'Proveedor2', '2023-07-06', 'Almacén C')
# (5148, 'Artículo5148', 'Jardín', 462.97, 7, 'Proveedor2', '2023-06-06', 'Almacén B')
# (5149, 'Producto5149', 'Moda', 118.76, 63, 'Proveedor1', '2023-05-27', 'Almacén C')
# (5150, 'Producto5150', 'Moda', 37.06, 36, 'Proveedor3', '2023-07-23', 'Almacén A')
# (5151, 'Artículo5151', 'Electrónica', 57.2, 99, 'Proveedor3', '2023-07-17', 'Almacén C')
# (5152, 'Artículo5152', 'Moda', 183.09, 11, 'Proveedor1', '2023-09-18', 'Almacén C')
# (5153, 'Objeto5153', 'Electrónica', 437.95, 96, 'Proveedor3', '2023-07-17', 'Almacén A')
# (5154, 'Objeto5154', 'Jardín', 454.66, 77, 'Proveedor1', '2023-10-11', 'Almacén A')
# (5155, 'Producto5155', 'Jardín', 478.01, 20, 'Proveedor3', '2023-06-23', 'Almacén A')
# (5156, 'Artículo5156', 'Jardín', 261.31, 59, 'Proveedor3', '2023-10-02', 'Almacén B')
# (5157, 'Artículo5157', 'Jardín', 222.91, 97, 'Proveedor2', '2023-01-24', 'Almacén B')
# (5158, 'Artículo5158', 'Electrónica', 382.82, 74, 'Proveedor2', '2023-08-06', 'Almacén A')
# (5159, 'Objeto5159', 'Hogar', 43.82, 29, 'Proveedor2', '2023-06-18', 'Almacén B')
# (5160, 'Artículo5160', 'Electrónica', 176.78, 19, 'Proveedor1', '2023-08-01', 'Almacén A')
# (5161, 'Artículo5161', 'Moda', 161.2, 31, 'Proveedor2', '2023-06-01', 'Almacén A')
# (5162, 'Objeto5162', 'Jardín', 479.91, 1, 'Proveedor2', '2023-11-14', 'Almacén A')
# (5163, 'Producto5163', 'Moda', 328.69, 44, 'Proveedor3', '2023-03-22', 'Almacén C')
# (5164, 'Producto5164', 'Hogar', 337.03, 47, 'Proveedor2', '2023-08-14', 'Almacén A')
# (5165, 'Producto5165', 'Jardín', 94.99, 45, 'Proveedor1', '2023-09-16', 'Almacén C')
# (5166, 'Artículo5166', 'Deportes', 188.67, 23, 'Proveedor3', '2023-03-14', 'Almacén B')
# (5167, 'Producto5167', 'Electrónica', 239.22, 29, 'Proveedor1', '2023-08-04', 'Almacén A')
# (5168, 'Producto5168', 'Moda', 382.57, 1, 'Proveedor1', '2023-12-17', 'Almacén A')
# (5169, 'Producto5169', 'Electrónica', 201.91, 92, 'Proveedor1', '2023-02-27', 'Almacén C')
# (5170, 'Artículo5170', 'Hogar', 43.19, 47, 'Proveedor1', '2023-09-08', 'Almacén A')
# (5171, 'Objeto5171', 'Hogar', 449.96, 58, 'Proveedor1', '2023-12-26', 'Almacén C')
# (5172, 'Objeto5172', 'Hogar', 457.68, 14, 'Proveedor2', '2023-09-11', 'Almacén A')
# (5173, 'Producto5173', 'Moda', 71.71, 83, 'Proveedor2', '2023-03-10', 'Almacén C')
# (5174, 'Artículo5174', 'Deportes', 124.8, 13, 'Proveedor1', '2023-05-06', 'Almacén B')
# (5175, 'Producto5175', 'Electrónica', 101.63, 85, 'Proveedor1', '2023-06-08', 'Almacén B')
# (5176, 'Producto5176', 'Hogar', 271.56, 61, 'Proveedor3', '2023-05-15', 'Almacén A')
# (5177, 'Objeto5177', 'Jardín', 93.38, 16, 'Proveedor2', '2023-04-23', 'Almacén B')
# (5178, 'Objeto5178', 'Jardín', 493.09, 31, 'Proveedor3', '2023-12-10', 'Almacén C')
# (5179, 'Artículo5179', 'Moda', 239.19, 88, 'Proveedor3', '2023-09-28', 'Almacén C')
# (5180, 'Artículo5180', 'Moda', 184.15, 37, 'Proveedor3', '2023-09-21', 'Almacén C')
# (5181, 'Artículo5181', 'Hogar', 495.36, 79, 'Proveedor1', '2023-04-15', 'Almacén C')
# (5182, 'Producto5182', 'Jardín', 29.98, 81, 'Proveedor2', '2023-09-26', 'Almacén A')
# (5183, 'Producto5183', 'Moda', 138.21, 5, 'Proveedor2', '2023-03-24', 'Almacén A')
# (5184, 'Producto5184', 'Moda', 194.22, 39, 'Proveedor3', '2023-09-06', 'Almacén C')
# (5185, 'Artículo5185', 'Hogar', 104.97, 26, 'Proveedor2', '2023-06-09', 'Almacén B')
# (5186, 'Artículo5186', 'Electrónica', 238.79, 57, 'Proveedor2', '2023-10-27', 'Almacén C')
# (5187, 'Producto5187', 'Electrónica', 166.19, 25, 'Proveedor1', '2023-07-24', 'Almacén B')
# (5188, 'Objeto5188', 'Jardín', 155.61, 78, 'Proveedor1', '2023-06-22', 'Almacén A')
# (5189, 'Artículo5189', 'Moda', 350.06, 80, 'Proveedor1', '2023-06-04', 'Almacén A')
# (5190, 'Artículo5190', 'Moda', 442.02, 38, 'Proveedor2', '2023-11-22', 'Almacén A')
# (5191, 'Objeto5191', 'Deportes', 190.26, 68, 'Proveedor2', '2023-04-13', 'Almacén B')
# (5192, 'Artículo5192', 'Moda', 494.18, 93, 'Proveedor3', '2023-04-09', 'Almacén C')
# (5193, 'Producto5193', 'Moda', 53.6, 28, 'Proveedor2', '2023-05-04', 'Almacén A')
# (5194, 'Objeto5194', 'Jardín', 297.97, 11, 'Proveedor3', '2023-10-25', 'Almacén A')
# (5195, 'Producto5195', 'Hogar', 159.05, 24, 'Proveedor3', '2023-08-23', 'Almacén A')
# (5196, 'Producto5196', 'Deportes', 464.48, 43, 'Proveedor2', '2023-08-16', 'Almacén B')
# (5197, 'Artículo5197', 'Deportes', 46.13, 28, 'Proveedor3', '2023-05-01', 'Almacén C')
# (5198, 'Producto5198', 'Jardín', 449.92, 91, 'Proveedor1', '2023-03-06', 'Almacén A')
# (5199, 'Objeto5199', 'Hogar', 273.85, 9, 'Proveedor2', '2023-01-09', 'Almacén A')
# (5200, 'Objeto5200', 'Hogar', 61.56, 20, 'Proveedor1', '2023-09-20', 'Almacén B')
# (5201, 'Objeto5201', 'Deportes', 246.26, 68, 'Proveedor3', '2023-07-22', 'Almacén C')
# (5202, 'Artículo5202', 'Deportes', 486.99, 54, 'Proveedor3', '2023-12-06', 'Almacén C')
# (5203, 'Producto5203', 'Electrónica', 179.7, 90, 'Proveedor3', '2023-12-16', 'Almacén C')
# (5204, 'Producto5204', 'Moda', 469, 35, 'Proveedor1', '2023-06-12', 'Almacén B')
# (5205, 'Artículo5205', 'Hogar', 52.72, 53, 'Proveedor1', '2023-11-24', 'Almacén B')
# (5206, 'Objeto5206', 'Electrónica', 263.51, 71, 'Proveedor2', '2023-12-16', 'Almacén B')
# (5207, 'Artículo5207', 'Moda', 408.04, 78, 'Proveedor1', '2023-11-20', 'Almacén B')
# (5208, 'Artículo5208', 'Electrónica', 290.09, 96, 'Proveedor3', '2023-07-01', 'Almacén C')
# (5209, 'Artículo5209', 'Deportes', 151.45, 13, 'Proveedor1', '2023-10-18', 'Almacén B')
# (5210, 'Objeto5210', 'Jardín', 86.54, 91, 'Proveedor1', '2023-03-15', 'Almacén B')
# (5211, 'Artículo5211', 'Jardín', 384.25, 61, 'Proveedor3', '2023-03-20', 'Almacén A')
# (5212, 'Objeto5212', 'Moda', 492.74, 83, 'Proveedor3', '2023-02-09', 'Almacén B')
# (5213, 'Producto5213', 'Hogar', 86.23, 7, 'Proveedor1', '2023-05-17', 'Almacén B')
# (5214, 'Producto5214', 'Hogar', 204.99, 7, 'Proveedor3', '2023-03-23', 'Almacén B')
# (5215, 'Artículo5215', 'Deportes', 383.59, 75, 'Proveedor2', '2023-01-08', 'Almacén C')
# (5216, 'Objeto5216', 'Jardín', 97.01, 74, 'Proveedor2', '2023-06-25', 'Almacén A')
# (5217, 'Objeto5217', 'Jardín', 419.78, 100, 'Proveedor2', '2023-05-25', 'Almacén C')
# (5218, 'Producto5218', 'Moda', 376.34, 7, 'Proveedor1', '2023-11-11', 'Almacén C')
# (5219, 'Producto5219', 'Moda', 406.63, 28, 'Proveedor2', '2023-10-19', 'Almacén B')
# (5220, 'Artículo5220', 'Moda', 269.24, 12, 'Proveedor3', '2023-02-09', 'Almacén C')
# (5221, 'Objeto5221', 'Deportes', 424.1, 67, 'Proveedor3', '2023-08-07', 'Almacén B')
# (5222, 'Artículo5222', 'Jardín', 20.62, 100, 'Proveedor3', '2023-07-26', 'Almacén C')
# (5223, 'Producto5223', 'Electrónica', 492.86, 37, 'Proveedor3', '2023-11-18', 'Almacén A')
# (5224, 'Artículo5224', 'Deportes', 370.21, 22, 'Proveedor3', '2023-07-15', 'Almacén A')
# (5225, 'Producto5225', 'Jardín', 301.4, 16, 'Proveedor2', '2023-12-05', 'Almacén A')
# (5226, 'Artículo5226', 'Jardín', 478.57, 83, 'Proveedor2', '2023-10-12', 'Almacén B')
# (5227, 'Objeto5227', 'Electrónica', 23.88, 15, 'Proveedor2', '2023-12-09', 'Almacén B')
# (5228, 'Objeto5228', 'Electrónica', 299.64, 14, 'Proveedor1', '2023-06-06', 'Almacén C')
# (5229, 'Producto5229', 'Deportes', 292.8, 97, 'Proveedor2', '2023-07-03', 'Almacén C')
# (5230, 'Objeto5230', 'Deportes', 308.2, 84, 'Proveedor1', '2023-02-27', 'Almacén C')
# (5231, 'Objeto5231', 'Hogar', 191.37, 47, 'Proveedor1', '2023-05-02', 'Almacén C')
# (5232, 'Artículo5232', 'Deportes', 213.15, 71, 'Proveedor1', '2023-08-03', 'Almacén B')
# (5233, 'Objeto5233', 'Deportes', 380.78, 19, 'Proveedor3', '2023-07-14', 'Almacén A')
# (5234, 'Objeto5234', 'Moda', 470.29, 98, 'Proveedor3', '2023-06-22', 'Almacén A')
# (5235, 'Producto5235', 'Hogar', 15.65, 56, 'Proveedor2', '2023-09-17', 'Almacén A')
# (5236, 'Producto5236', 'Hogar', 287.93, 91, 'Proveedor2', '2023-08-24', 'Almacén B')
# (5237, 'Artículo5237', 'Jardín', 479.37, 47, 'Proveedor3', '2023-10-28', 'Almacén A')
# (5238, 'Objeto5238', 'Jardín', 247.03, 46, 'Proveedor3', '2023-01-11', 'Almacén B')
# (5239, 'Producto5239', 'Hogar', 460.08, 49, 'Proveedor1', '2023-11-24', 'Almacén B')
# (5240, 'Producto5240', 'Jardín', 71.55, 27, 'Proveedor1', '2023-06-28', 'Almacén A')
# (5241, 'Producto5241', 'Electrónica', 291.1, 67, 'Proveedor1', '2023-06-09', 'Almacén C')
# (5242, 'Artículo5242', 'Jardín', 101.01, 62, 'Proveedor2', '2023-04-03', 'Almacén A')
# (5243, 'Producto5243', 'Electrónica', 319.66, 66, 'Proveedor1', '2023-07-03', 'Almacén B')
# (5244, 'Producto5244', 'Jardín', 118.61, 62, 'Proveedor1', '2023-11-07', 'Almacén A')
# (5245, 'Producto5245', 'Hogar', 246.97, 43, 'Proveedor1', '2023-11-28', 'Almacén B')
# (5246, 'Objeto5246', 'Deportes', 354.26, 79, 'Proveedor3', '2023-09-26', 'Almacén C')
# (5247, 'Objeto5247', 'Hogar', 345.97, 7, 'Proveedor3', '2023-03-01', 'Almacén C')
# (5248, 'Artículo5248', 'Deportes', 247.57, 42, 'Proveedor1', '2023-06-09', 'Almacén C')
# (5249, 'Producto5249', 'Moda', 499.83, 29, 'Proveedor2', '2023-12-18', 'Almacén A')
# (5250, 'Objeto5250', 'Hogar', 370.76, 63, 'Proveedor2', '2023-11-06', 'Almacén C')
# (5251, 'Artículo5251', 'Moda', 310.33, 16, 'Proveedor2', '2023-10-27', 'Almacén B')
# (5252, 'Artículo5252', 'Deportes', 218.56, 93, 'Proveedor3', '2023-11-15', 'Almacén B')
# (5253, 'Objeto5253', 'Jardín', 411.91, 65, 'Proveedor3', '2023-04-05', 'Almacén A')
# (5254, 'Artículo5254', 'Moda', 192.51, 90, 'Proveedor3', '2023-09-01', 'Almacén C')
# (5255, 'Producto5255', 'Moda', 47.06, 47, 'Proveedor2', '2023-01-20', 'Almacén A')
# (5256, 'Producto5256', 'Hogar', 180.71, 45, 'Proveedor2', '2023-03-17', 'Almacén A')
# (5257, 'Objeto5257', 'Deportes', 163.31, 39, 'Proveedor2', '2023-07-01', 'Almacén A')
# (5258, 'Objeto5258', 'Electrónica', 498.11, 48, 'Proveedor2', '2023-04-10', 'Almacén A')
# (5259, 'Objeto5259', 'Hogar', 374.59, 73, 'Proveedor1', '2023-10-11', 'Almacén B')
# (5260, 'Producto5260', 'Electrónica', 470.2, 98, 'Proveedor3', '2023-06-06', 'Almacén C')
# (5261, 'Producto5261', 'Jardín', 433.42, 91, 'Proveedor1', '2023-09-11', 'Almacén A')
# (5262, 'Objeto5262', 'Jardín', 342.32, 36, 'Proveedor2', '2023-01-28', 'Almacén C')
# (5263, 'Objeto5263', 'Deportes', 431.08, 50, 'Proveedor3', '2023-04-23', 'Almacén C')
# (5264, 'Producto5264', 'Hogar', 195.99, 53, 'Proveedor1', '2023-01-14', 'Almacén C')
# (5265, 'Objeto5265', 'Electrónica', 149.12, 88, 'Proveedor2', '2023-12-03', 'Almacén B')
# (5266, 'Objeto5266', 'Electrónica', 92.2, 19, 'Proveedor1', '2023-02-26', 'Almacén C')
# (5267, 'Producto5267', 'Jardín', 368.15, 59, 'Proveedor3', '2023-10-11', 'Almacén A')
# (5268, 'Producto5268', 'Jardín', 186.63, 9, 'Proveedor1', '2023-11-05', 'Almacén B')
# (5269, 'Producto5269', 'Hogar', 337.13, 34, 'Proveedor2', '2023-03-10', 'Almacén A')
# (5270, 'Objeto5270', 'Moda', 111.96, 2, 'Proveedor1', '2023-12-06', 'Almacén B')
# (5271, 'Artículo5271', 'Electrónica', 54.28, 77, 'Proveedor2', '2023-09-01', 'Almacén C')
# (5272, 'Artículo5272', 'Hogar', 11.52, 47, 'Proveedor1', '2023-02-18', 'Almacén A')
# (5273, 'Objeto5273', 'Deportes', 493.8, 7, 'Proveedor2', '2023-04-17', 'Almacén C')
# (5274, 'Artículo5274', 'Jardín', 356.91, 99, 'Proveedor2', '2023-12-26', 'Almacén B')
# (5275, 'Objeto5275', 'Hogar', 423.84, 44, 'Proveedor2', '2023-06-17', 'Almacén A')
# (5276, 'Artículo5276', 'Hogar', 131.34, 34, 'Proveedor2', '2023-10-15', 'Almacén C')
# (5277, 'Objeto5277', 'Deportes', 152.22, 99, 'Proveedor2', '2023-02-06', 'Almacén C')
# (5278, 'Artículo5278', 'Moda', 473.68, 98, 'Proveedor3', '2023-03-13', 'Almacén A')
# (5279, 'Producto5279', 'Hogar', 487.83, 76, 'Proveedor1', '2023-06-05', 'Almacén B')
# (5280, 'Objeto5280', 'Moda', 468.94, 82, 'Proveedor3', '2023-01-25', 'Almacén C')
# (5281, 'Objeto5281', 'Hogar', 499.37, 47, 'Proveedor1', '2023-07-12', 'Almacén B')
# (5282, 'Producto5282', 'Jardín', 362.87, 100, 'Proveedor1', '2023-04-12', 'Almacén A')
# (5283, 'Objeto5283', 'Electrónica', 443.37, 99, 'Proveedor1', '2023-08-22', 'Almacén C')
# (5284, 'Producto5284', 'Electrónica', 215.68, 19, 'Proveedor1', '2023-11-28', 'Almacén C')
# (5285, 'Objeto5285', 'Hogar', 305.7, 22, 'Proveedor3', '2023-08-13', 'Almacén C')
# (5286, 'Producto5286', 'Jardín', 79.4, 70, 'Proveedor3', '2023-09-27', 'Almacén B')
# (5287, 'Artículo5287', 'Hogar', 493.3, 73, 'Proveedor2', '2023-11-27', 'Almacén C')
# (5288, 'Producto5288', 'Moda', 417.67, 86, 'Proveedor2', '2023-01-10', 'Almacén C')
# (5289, 'Producto5289', 'Jardín', 225.99, 13, 'Proveedor1', '2023-07-28', 'Almacén A')
# (5290, 'Artículo5290', 'Jardín', 168.65, 97, 'Proveedor3', '2023-04-09', 'Almacén C')
# (5291, 'Objeto5291', 'Electrónica', 152.17, 11, 'Proveedor2', '2023-03-03', 'Almacén A')
# (5292, 'Objeto5292', 'Electrónica', 465.6, 6, 'Proveedor1', '2023-06-03', 'Almacén A')
# (5293, 'Objeto5293', 'Moda', 51.2, 70, 'Proveedor2', '2023-04-27', 'Almacén A')
# (5294, 'Producto5294', 'Hogar', 97.3, 17, 'Proveedor2', '2023-12-17', 'Almacén B')
# (5295, 'Producto5295', 'Jardín', 120.6, 55, 'Proveedor3', '2023-06-02', 'Almacén C')
# (5296, 'Objeto5296', 'Jardín', 129.3, 74, 'Proveedor3', '2023-07-07', 'Almacén C')
# (5297, 'Artículo5297', 'Moda', 230.28, 2, 'Proveedor3', '2023-06-11', 'Almacén B')
# (5298, 'Objeto5298', 'Hogar', 469.24, 30, 'Proveedor2', '2023-09-16', 'Almacén B')
# (5299, 'Artículo5299', 'Jardín', 181.54, 38, 'Proveedor1', '2023-04-01', 'Almacén C')
# (5300, 'Producto5300', 'Moda', 233.58, 77, 'Proveedor3', '2023-08-18', 'Almacén A')
# (5301, 'Objeto5301', 'Jardín', 46.98, 14, 'Proveedor2', '2023-12-01', 'Almacén C')
# (5302, 'Artículo5302', 'Moda', 281.16, 17, 'Proveedor2', '2023-06-26', 'Almacén A')
# (5303, 'Producto5303', 'Moda', 362.91, 14, 'Proveedor1', '2023-12-18', 'Almacén A')
# (5304, 'Objeto5304', 'Electrónica', 350.92, 29, 'Proveedor2', '2023-06-28', 'Almacén B')
# (5305, 'Producto5305', 'Deportes', 74.79, 55, 'Proveedor3', '2023-10-14', 'Almacén B')
# (5306, 'Artículo5306', 'Jardín', 369.16, 78, 'Proveedor1', '2023-09-16', 'Almacén B')
# (5307, 'Artículo5307', 'Moda', 199.83, 4, 'Proveedor2', '2023-06-13', 'Almacén C')
# (5308, 'Producto5308', 'Deportes', 232.32, 36, 'Proveedor3', '2023-05-04', 'Almacén C')
# (5309, 'Producto5309', 'Jardín', 121.47, 55, 'Proveedor2', '2023-11-15', 'Almacén B')
# (5310, 'Producto5310', 'Hogar', 463.76, 91, 'Proveedor3', '2023-09-16', 'Almacén A')
# (5311, 'Objeto5311', 'Moda', 146.57, 2, 'Proveedor1', '2023-09-25', 'Almacén B')
# (5312, 'Objeto5312', 'Hogar', 21.86, 40, 'Proveedor2', '2023-08-09', 'Almacén B')
# (5313, 'Objeto5313', 'Jardín', 359.59, 31, 'Proveedor3', '2023-08-16', 'Almacén C')
# (5314, 'Producto5314', 'Electrónica', 172.88, 71, 'Proveedor2', '2023-01-22', 'Almacén A')
# (5315, 'Objeto5315', 'Jardín', 350.04, 73, 'Proveedor3', '2023-06-21', 'Almacén A')
# (5316, 'Producto5316', 'Jardín', 292.98, 15, 'Proveedor2', '2023-04-10', 'Almacén B')
# (5317, 'Objeto5317', 'Deportes', 416, 22, 'Proveedor1', '2023-07-19', 'Almacén C')
# (5318, 'Artículo5318', 'Moda', 319.5, 59, 'Proveedor1', '2023-03-23', 'Almacén C')
# (5319, 'Objeto5319', 'Deportes', 235.2, 92, 'Proveedor1', '2023-02-07', 'Almacén A')
# (5320, 'Objeto5320', 'Hogar', 56.16, 79, 'Proveedor1', '2023-02-20', 'Almacén C')
# (5321, 'Producto5321', 'Jardín', 381.7, 23, 'Proveedor3', '2023-12-12', 'Almacén A')
# (5322, 'Producto5322', 'Hogar', 406.51, 45, 'Proveedor2', '2023-02-22', 'Almacén B')
# (5323, 'Objeto5323', 'Deportes', 409.22, 49, 'Proveedor2', '2023-05-20', 'Almacén C')
# (5324, 'Artículo5324', 'Moda', 105.13, 13, 'Proveedor1', '2023-01-04', 'Almacén C')
# (5325, 'Producto5325', 'Moda', 55.01, 74, 'Proveedor3', '2023-12-24', 'Almacén C')
# (5326, 'Artículo5326', 'Deportes', 267.1, 43, 'Proveedor2', '2023-05-17', 'Almacén A')
# (5327, 'Producto5327', 'Jardín', 253.58, 4, 'Proveedor3', '2023-03-03', 'Almacén B')
# (5328, 'Producto5328', 'Hogar', 132.27, 59, 'Proveedor1', '2023-11-17', 'Almacén A')
# (5329, 'Artículo5329', 'Jardín', 489.43, 91, 'Proveedor3', '2023-02-05', 'Almacén A')
# (5330, 'Objeto5330', 'Electrónica', 275.55, 9, 'Proveedor2', '2023-08-27', 'Almacén A')
# (5331, 'Objeto5331', 'Jardín', 494.05, 44, 'Proveedor3', '2023-01-14', 'Almacén B')
# (5332, 'Objeto5332', 'Jardín', 310.55, 68, 'Proveedor2', '2023-02-28', 'Almacén C')
# (5333, 'Artículo5333', 'Electrónica', 456.9, 88, 'Proveedor1', '2023-07-08', 'Almacén C')
# (5334, 'Artículo5334', 'Moda', 369.84, 90, 'Proveedor2', '2023-07-27', 'Almacén B')
# (5335, 'Artículo5335', 'Deportes', 349.02, 100, 'Proveedor1', '2023-03-13', 'Almacén C')
# (5336, 'Artículo5336', 'Hogar', 326.71, 19, 'Proveedor2', '2023-07-03', 'Almacén B')
# (5337, 'Producto5337', 'Jardín', 340.28, 94, 'Proveedor3', '2023-08-15', 'Almacén C')
# (5338, 'Artículo5338', 'Deportes', 59.06, 17, 'Proveedor2', '2023-11-21', 'Almacén C')
# (5339, 'Artículo5339', 'Deportes', 16.52, 58, 'Proveedor2', '2023-06-26', 'Almacén B')
# (5340, 'Objeto5340', 'Deportes', 47.03, 9, 'Proveedor3', '2023-12-20', 'Almacén C')
# (5341, 'Artículo5341', 'Moda', 343.05, 99, 'Proveedor3', '2023-06-06', 'Almacén B')
# (5342, 'Objeto5342', 'Moda', 81.32, 76, 'Proveedor3', '2023-01-13', 'Almacén C')
# (5343, 'Artículo5343', 'Jardín', 103.77, 86, 'Proveedor3', '2023-05-08', 'Almacén B')
# (5344, 'Objeto5344', 'Moda', 460.65, 33, 'Proveedor3', '2023-11-19', 'Almacén B')
# (5345, 'Artículo5345', 'Moda', 205.38, 70, 'Proveedor2', '2023-01-23', 'Almacén A')
# (5346, 'Producto5346', 'Electrónica', 187.22, 65, 'Proveedor3', '2023-05-05', 'Almacén C')
# (5347, 'Objeto5347', 'Hogar', 137.28, 90, 'Proveedor2', '2023-11-17', 'Almacén B')
# (5348, 'Producto5348', 'Deportes', 101.12, 35, 'Proveedor3', '2023-03-06', 'Almacén C')
# (5349, 'Artículo5349', 'Moda', 365.06, 45, 'Proveedor1', '2023-07-20', 'Almacén A')
# (5350, 'Objeto5350', 'Moda', 193.14, 98, 'Proveedor3', '2023-04-03', 'Almacén B')
# (5351, 'Objeto5351', 'Deportes', 397.67, 15, 'Proveedor1', '2023-12-21', 'Almacén B')
# (5352, 'Objeto5352', 'Jardín', 460.51, 84, 'Proveedor2', '2023-01-17', 'Almacén A')
# (5353, 'Artículo5353', 'Deportes', 36.57, 22, 'Proveedor1', '2023-08-09', 'Almacén C')
# (5354, 'Artículo5354', 'Electrónica', 321.6, 32, 'Proveedor1', '2023-08-04', 'Almacén A')
# (5355, 'Producto5355', 'Hogar', 203.66, 79, 'Proveedor3', '2023-02-21', 'Almacén B')
# (5356, 'Producto5356', 'Deportes', 324.19, 1, 'Proveedor3', '2023-02-01', 'Almacén B')
# (5357, 'Producto5357', 'Jardín', 161.51, 64, 'Proveedor3', '2023-02-09', 'Almacén C')
# (5358, 'Artículo5358', 'Moda', 17.14, 67, 'Proveedor3', '2023-01-06', 'Almacén C')
# (5359, 'Producto5359', 'Jardín', 305.23, 86, 'Proveedor1', '2023-05-27', 'Almacén B')
# (5360, 'Artículo5360', 'Electrónica', 243.1, 88, 'Proveedor3', '2023-05-17', 'Almacén C')
# (5361, 'Artículo5361', 'Jardín', 79.45, 20, 'Proveedor3', '2023-01-11', 'Almacén C')
# (5362, 'Producto5362', 'Hogar', 342.3, 100, 'Proveedor2', '2023-12-11', 'Almacén A')
# (5363, 'Producto5363', 'Electrónica', 349.97, 97, 'Proveedor2', '2023-05-03', 'Almacén B')
# (5364, 'Objeto5364', 'Moda', 393.34, 12, 'Proveedor3', '2023-04-05', 'Almacén C')
# (5365, 'Producto5365', 'Hogar', 454.86, 24, 'Proveedor2', '2023-01-16', 'Almacén B')
# (5366, 'Objeto5366', 'Hogar', 496.96, 19, 'Proveedor2', '2023-07-26', 'Almacén A')
# (5367, 'Objeto5367', 'Moda', 338.2, 55, 'Proveedor3', '2023-07-18', 'Almacén C')
# (5368, 'Artículo5368', 'Deportes', 416.42, 75, 'Proveedor1', '2023-07-13', 'Almacén A')
# (5369, 'Artículo5369', 'Moda', 205.4, 74, 'Proveedor1', '2023-02-21', 'Almacén B')
# (5370, 'Objeto5370', 'Hogar', 259.74, 96, 'Proveedor1', '2023-06-26', 'Almacén C')
# (5371, 'Producto5371', 'Jardín', 322.03, 62, 'Proveedor3', '2023-06-21', 'Almacén A')
# (5372, 'Producto5372', 'Moda', 17.65, 69, 'Proveedor2', '2023-12-08', 'Almacén B')
# (5373, 'Producto5373', 'Hogar', 27.59, 60, 'Proveedor1', '2023-02-06', 'Almacén C')
# (5374, 'Objeto5374', 'Jardín', 112.77, 95, 'Proveedor3', '2023-02-17', 'Almacén C')
# (5375, 'Artículo5375', 'Moda', 249.48, 43, 'Proveedor3', '2023-01-11', 'Almacén B')
# (5376, 'Objeto5376', 'Jardín', 73.92, 39, 'Proveedor1', '2023-01-18', 'Almacén A')
# (5377, 'Artículo5377', 'Hogar', 187.69, 75, 'Proveedor3', '2023-06-05', 'Almacén B')
# (5378, 'Artículo5378', 'Hogar', 126.15, 23, 'Proveedor1', '2023-08-21', 'Almacén C')
# (5379, 'Artículo5379', 'Moda', 359.22, 86, 'Proveedor3', '2023-09-14', 'Almacén A')
# (5380, 'Artículo5380', 'Hogar', 150.55, 92, 'Proveedor2', '2023-05-02', 'Almacén B')
# (5381, 'Artículo5381', 'Jardín', 228.98, 34, 'Proveedor1', '2023-05-19', 'Almacén A')
# (5382, 'Objeto5382', 'Deportes', 425.53, 41, 'Proveedor1', '2023-09-04', 'Almacén A')
# (5383, 'Objeto5383', 'Hogar', 463.65, 29, 'Proveedor1', '2023-07-19', 'Almacén B')
# (5384, 'Artículo5384', 'Hogar', 461.49, 73, 'Proveedor1', '2023-10-07', 'Almacén B')
# (5385, 'Producto5385', 'Electrónica', 84.91, 95, 'Proveedor2', '2023-04-11', 'Almacén B')
# (5386, 'Producto5386', 'Deportes', 280.95, 97, 'Proveedor3', '2023-09-26', 'Almacén C')
# (5387, 'Objeto5387', 'Deportes', 458.83, 48, 'Proveedor2', '2023-02-11', 'Almacén A')
# (5388, 'Artículo5388', 'Jardín', 187.56, 64, 'Proveedor2', '2023-07-12', 'Almacén A')
# (5389, 'Producto5389', 'Deportes', 292.16, 94, 'Proveedor1', '2023-04-26', 'Almacén A')
# (5390, 'Artículo5390', 'Electrónica', 184.54, 43, 'Proveedor3', '2023-12-07', 'Almacén B')
# (5391, 'Producto5391', 'Deportes', 86.44, 17, 'Proveedor2', '2023-05-22', 'Almacén B')
# (5392, 'Objeto5392', 'Jardín', 280.05, 60, 'Proveedor1', '2023-04-13', 'Almacén C')
# (5393, 'Artículo5393', 'Hogar', 202.45, 23, 'Proveedor1', '2023-04-01', 'Almacén A')
# (5394, 'Objeto5394', 'Jardín', 404.52, 58, 'Proveedor2', '2023-04-25', 'Almacén B')
# (5395, 'Artículo5395', 'Deportes', 198.61, 32, 'Proveedor1', '2023-03-07', 'Almacén B')
# (5396, 'Artículo5396', 'Deportes', 189.11, 8, 'Proveedor3', '2023-09-06', 'Almacén C')
# (5397, 'Producto5397', 'Deportes', 256.75, 37, 'Proveedor2', '2023-01-22', 'Almacén C')
# (5398, 'Artículo5398', 'Moda', 192.8, 2, 'Proveedor3', '2023-05-16', 'Almacén A')
# (5399, 'Objeto5399', 'Moda', 265.6, 78, 'Proveedor1', '2023-11-07', 'Almacén B')
# (5400, 'Objeto5400', 'Electrónica', 64.76, 14, 'Proveedor2', '2023-03-14', 'Almacén A')
# (5401, 'Objeto5401', 'Jardín', 138.22, 27, 'Proveedor3', '2023-04-27', 'Almacén A')
# (5402, 'Artículo5402', 'Jardín', 82.14, 82, 'Proveedor1', '2023-02-08', 'Almacén C')
# (5403, 'Producto5403', 'Electrónica', 148.4, 30, 'Proveedor3', '2023-11-14', 'Almacén A')
# (5404, 'Producto5404', 'Moda', 15.74, 36, 'Proveedor1', '2023-01-15', 'Almacén A')
# (5405, 'Producto5405', 'Deportes', 148.81, 69, 'Proveedor2', '2023-03-16', 'Almacén B')
# (5406, 'Artículo5406', 'Hogar', 487.73, 14, 'Proveedor3', '2023-12-03', 'Almacén A')
# (5407, 'Artículo5407', 'Moda', 90.5, 45, 'Proveedor1', '2023-10-18', 'Almacén A')
# (5408, 'Producto5408', 'Electrónica', 392.68, 84, 'Proveedor2', '2023-04-10', 'Almacén A')
# (5409, 'Objeto5409', 'Hogar', 147.96, 57, 'Proveedor1', '2023-07-07', 'Almacén C')
# (5410, 'Objeto5410', 'Jardín', 99.59, 26, 'Proveedor2', '2023-02-12', 'Almacén C')
# (5411, 'Producto5411', 'Hogar', 139.43, 97, 'Proveedor1', '2023-06-15', 'Almacén C')
# (5412, 'Artículo5412', 'Deportes', 55.06, 3, 'Proveedor1', '2023-02-06', 'Almacén C')
# (5413, 'Objeto5413', 'Deportes', 270.52, 31, 'Proveedor3', '2023-07-28', 'Almacén B')
# (5414, 'Artículo5414', 'Moda', 66.73, 6, 'Proveedor3', '2023-11-28', 'Almacén A')
# (5415, 'Producto5415', 'Electrónica', 271.93, 9, 'Proveedor1', '2023-03-28', 'Almacén C')
# (5416, 'Producto5416', 'Jardín', 239.84, 54, 'Proveedor2', '2023-09-01', 'Almacén C')
# (5417, 'Objeto5417', 'Deportes', 181.18, 90, 'Proveedor3', '2023-10-07', 'Almacén B')
# (5418, 'Objeto5418', 'Jardín', 140.74, 90, 'Proveedor1', '2023-08-21', 'Almacén A')
# (5419, 'Objeto5419', 'Jardín', 319.33, 40, 'Proveedor3', '2023-07-09', 'Almacén B')
# (5420, 'Artículo5420', 'Jardín', 493.68, 49, 'Proveedor1', '2023-07-18', 'Almacén A')
# (5421, 'Objeto5421', 'Moda', 478.89, 85, 'Proveedor2', '2023-09-04', 'Almacén C')
# (5422, 'Objeto5422', 'Deportes', 240.75, 54, 'Proveedor2', '2023-05-18', 'Almacén C')
# (5423, 'Producto5423', 'Jardín', 247.1, 53, 'Proveedor1', '2023-12-06', 'Almacén C')
# (5424, 'Artículo5424', 'Electrónica', 395.58, 77, 'Proveedor3', '2023-01-24', 'Almacén C')
# (5425, 'Producto5425', 'Jardín', 279.88, 17, 'Proveedor3', '2023-02-15', 'Almacén C')
# (5426, 'Producto5426', 'Jardín', 194.43, 34, 'Proveedor1', '2023-11-12', 'Almacén A')
# (5427, 'Producto5427', 'Jardín', 92.23, 26, 'Proveedor1', '2023-04-09', 'Almacén B')
# (5428, 'Artículo5428', 'Deportes', 173.27, 64, 'Proveedor3', '2023-04-09', 'Almacén B')
# (5429, 'Producto5429', 'Hogar', 31.07, 54, 'Proveedor1', '2023-06-11', 'Almacén A')
# (5430, 'Artículo5430', 'Deportes', 164.56, 41, 'Proveedor2', '2023-02-22', 'Almacén A')
# (5431, 'Producto5431', 'Electrónica', 69.11, 6, 'Proveedor3', '2023-11-04', 'Almacén B')
# (5432, 'Objeto5432', 'Jardín', 15.35, 15, 'Proveedor1', '2023-04-28', 'Almacén C')
# (5433, 'Objeto5433', 'Moda', 122.8, 44, 'Proveedor1', '2023-12-17', 'Almacén B')
# (5434, 'Objeto5434', 'Deportes', 222.97, 6, 'Proveedor2', '2023-08-14', 'Almacén A')
# (5435, 'Objeto5435', 'Jardín', 350.74, 21, 'Proveedor1', '2023-10-15', 'Almacén A')
# (5436, 'Objeto5436', 'Jardín', 293.27, 99, 'Proveedor1', '2023-04-06', 'Almacén C')
# (5437, 'Producto5437', 'Jardín', 484.54, 76, 'Proveedor2', '2023-05-21', 'Almacén B')
# (5438, 'Producto5438', 'Hogar', 254.57, 14, 'Proveedor1', '2023-02-04', 'Almacén C')
# (5439, 'Producto5439', 'Moda', 297.86, 19, 'Proveedor3', '2023-01-06', 'Almacén C')
# (5440, 'Objeto5440', 'Jardín', 168.23, 94, 'Proveedor3', '2023-04-23', 'Almacén A')
# (5441, 'Producto5441', 'Moda', 118.7, 53, 'Proveedor1', '2023-08-02', 'Almacén A')
# (5442, 'Producto5442', 'Deportes', 216.47, 76, 'Proveedor3', '2023-03-07', 'Almacén A')
# (5443, 'Artículo5443', 'Electrónica', 163.15, 47, 'Proveedor2', '2023-05-23', 'Almacén B')
# (5444, 'Objeto5444', 'Jardín', 287.33, 30, 'Proveedor2', '2023-10-04', 'Almacén A')
# (5445, 'Artículo5445', 'Hogar', 395.49, 32, 'Proveedor1', '2023-04-24', 'Almacén C')
# (5446, 'Producto5446', 'Electrónica', 21.29, 86, 'Proveedor2', '2023-01-21', 'Almacén A')
# (5447, 'Producto5447', 'Deportes', 201.86, 68, 'Proveedor1', '2023-01-26', 'Almacén C')
# (5448, 'Producto5448', 'Deportes', 469.89, 35, 'Proveedor1', '2023-09-18', 'Almacén A')
# (5449, 'Artículo5449', 'Electrónica', 299.65, 31, 'Proveedor3', '2023-07-07', 'Almacén B')
# (5450, 'Producto5450', 'Moda', 307.79, 91, 'Proveedor3', '2023-12-04', 'Almacén A')
# (5451, 'Artículo5451', 'Deportes', 373.79, 98, 'Proveedor2', '2023-06-15', 'Almacén C')
# (5452, 'Objeto5452', 'Deportes', 337.59, 16, 'Proveedor2', '2023-07-10', 'Almacén C')
# (5453, 'Producto5453', 'Moda', 217.69, 96, 'Proveedor3', '2023-12-11', 'Almacén A')
# (5454, 'Producto5454', 'Electrónica', 360.94, 69, 'Proveedor3', '2023-04-09', 'Almacén A')
# (5455, 'Artículo5455', 'Electrónica', 60.18, 78, 'Proveedor3', '2023-09-14', 'Almacén B')
# (5456, 'Producto5456', 'Hogar', 351.21, 19, 'Proveedor2', '2023-08-15', 'Almacén B')
# (5457, 'Artículo5457', 'Electrónica', 273.73, 22, 'Proveedor2', '2023-01-25', 'Almacén B')
# (5458, 'Producto5458', 'Jardín', 362.26, 64, 'Proveedor3', '2023-07-10', 'Almacén B')
# (5459, 'Artículo5459', 'Moda', 16.12, 73, 'Proveedor1', '2023-11-18', 'Almacén B')
# (5460, 'Producto5460', 'Hogar', 376.72, 91, 'Proveedor1', '2023-12-16', 'Almacén B')
# (5461, 'Objeto5461', 'Moda', 124.35, 44, 'Proveedor3', '2023-10-07', 'Almacén B')
# (5462, 'Producto5462', 'Electrónica', 453.5, 78, 'Proveedor1', '2023-02-08', 'Almacén C')
# (5463, 'Objeto5463', 'Electrónica', 305.48, 35, 'Proveedor1', '2023-10-09', 'Almacén C')
# (5464, 'Objeto5464', 'Moda', 368.12, 58, 'Proveedor3', '2023-04-09', 'Almacén A')
# (5465, 'Objeto5465', 'Hogar', 51.57, 99, 'Proveedor3', '2023-12-17', 'Almacén B')
# (5466, 'Producto5466', 'Electrónica', 148.39, 84, 'Proveedor3', '2023-01-17', 'Almacén A')
# (5467, 'Producto5467', 'Moda', 182.14, 63, 'Proveedor2', '2023-06-12', 'Almacén A')
# (5468, 'Objeto5468', 'Electrónica', 449.81, 28, 'Proveedor1', '2023-04-08', 'Almacén B')
# (5469, 'Producto5469', 'Hogar', 210.09, 49, 'Proveedor3', '2023-07-05', 'Almacén C')
# (5470, 'Objeto5470', 'Moda', 10.64, 92, 'Proveedor2', '2023-03-13', 'Almacén B')
# (5471, 'Artículo5471', 'Hogar', 359.31, 90, 'Proveedor2', '2023-05-22', 'Almacén C')
# (5472, 'Objeto5472', 'Hogar', 445.5, 18, 'Proveedor2', '2023-09-04', 'Almacén B')
# (5473, 'Producto5473', 'Jardín', 44.67, 100, 'Proveedor3', '2023-05-12', 'Almacén C')
# (5474, 'Producto5474', 'Deportes', 58.86, 10, 'Proveedor2', '2023-08-11', 'Almacén B')
# (5475, 'Artículo5475', 'Deportes', 64.48, 53, 'Proveedor1', '2023-04-15', 'Almacén C')
# (5476, 'Artículo5476', 'Electrónica', 458.44, 63, 'Proveedor3', '2023-08-17', 'Almacén C')
# (5477, 'Artículo5477', 'Moda', 419.25, 64, 'Proveedor1', '2023-09-16', 'Almacén B')
# (5478, 'Artículo5478', 'Moda', 312.89, 6, 'Proveedor2', '2023-08-06', 'Almacén C')
# (5479, 'Artículo5479', 'Moda', 250.37, 88, 'Proveedor2', '2023-03-08', 'Almacén A')
# (5480, 'Objeto5480', 'Electrónica', 83.92, 60, 'Proveedor3', '2023-01-13', 'Almacén B')
# (5481, 'Objeto5481', 'Electrónica', 355.96, 33, 'Proveedor2', '2023-12-14', 'Almacén A')
# (5482, 'Producto5482', 'Deportes', 217.91, 51, 'Proveedor2', '2023-10-02', 'Almacén C')
# (5483, 'Artículo5483', 'Moda', 415.99, 26, 'Proveedor1', '2023-11-03', 'Almacén C')
# (5484, 'Objeto5484', 'Electrónica', 333.25, 30, 'Proveedor1', '2023-03-07', 'Almacén B')
# (5485, 'Objeto5485', 'Electrónica', 44.32, 74, 'Proveedor3', '2023-03-21', 'Almacén B')
# (5486, 'Objeto5486', 'Electrónica', 42.87, 68, 'Proveedor2', '2023-07-23', 'Almacén A')
# (5487, 'Artículo5487', 'Jardín', 470.43, 38, 'Proveedor2', '2023-08-21', 'Almacén C')
# (5488, 'Artículo5488', 'Moda', 361.32, 18, 'Proveedor2', '2023-06-15', 'Almacén C')
# (5489, 'Producto5489', 'Electrónica', 480.53, 43, 'Proveedor3', '2023-10-16', 'Almacén C')
# (5490, 'Producto5490', 'Electrónica', 86.74, 23, 'Proveedor1', '2023-06-10', 'Almacén B')
# (5491, 'Producto5491', 'Moda', 160.83, 54, 'Proveedor3', '2023-11-02', 'Almacén A')
# (5492, 'Producto5492', 'Jardín', 54.69, 9, 'Proveedor2', '2023-04-26', 'Almacén A')
# (5493, 'Objeto5493', 'Electrónica', 33.85, 88, 'Proveedor3', '2023-05-26', 'Almacén C')
# (5494, 'Artículo5494', 'Jardín', 14.49, 62, 'Proveedor3', '2023-09-06', 'Almacén A')
# (5495, 'Producto5495', 'Deportes', 267.95, 19, 'Proveedor1', '2023-07-10', 'Almacén B')
# (5496, 'Producto5496', 'Hogar', 180.73, 80, 'Proveedor2', '2023-03-02', 'Almacén C')
# (5497, 'Objeto5497', 'Deportes', 76.77, 53, 'Proveedor1', '2023-08-19', 'Almacén C')
# (5498, 'Producto5498', 'Jardín', 155.91, 53, 'Proveedor3', '2023-04-05', 'Almacén B')
# (5499, 'Objeto5499', 'Moda', 450.78, 58, 'Proveedor1', '2023-05-05', 'Almacén C')
# (5500, 'Objeto5500', 'Hogar', 462.98, 3, 'Proveedor3', '2023-07-18', 'Almacén C')
# (5501, 'Objeto5501', 'Moda', 142.1, 33, 'Proveedor3', '2023-01-01', 'Almacén A')
# (5502, 'Producto5502', 'Moda', 282.86, 94, 'Proveedor3', '2023-03-25', 'Almacén C')
# (5503, 'Artículo5503', 'Moda', 325.78, 7, 'Proveedor3', '2023-08-21', 'Almacén A')
# (5504, 'Artículo5504', 'Deportes', 454.11, 92, 'Proveedor1', '2023-04-23', 'Almacén A')
# (5505, 'Producto5505', 'Hogar', 267.07, 44, 'Proveedor3', '2023-05-14', 'Almacén B')
# (5506, 'Objeto5506', 'Electrónica', 114.83, 18, 'Proveedor2', '2023-04-17', 'Almacén B')
# (5507, 'Objeto5507', 'Jardín', 244.96, 17, 'Proveedor1', '2023-11-16', 'Almacén C')
# (5508, 'Artículo5508', 'Hogar', 252.74, 14, 'Proveedor3', '2023-12-08', 'Almacén B')
# (5509, 'Objeto5509', 'Deportes', 327.01, 10, 'Proveedor3', '2023-08-16', 'Almacén B')
# (5510, 'Artículo5510', 'Jardín', 349.38, 38, 'Proveedor2', '2023-02-18', 'Almacén A')
# (5511, 'Producto5511', 'Hogar', 347.74, 73, 'Proveedor3', '2023-01-22', 'Almacén B')
# (5512, 'Artículo5512', 'Jardín', 374.53, 19, 'Proveedor1', '2023-04-09', 'Almacén C')
# (5513, 'Producto5513', 'Hogar', 228.81, 76, 'Proveedor2', '2023-03-22', 'Almacén A')
# (5514, 'Objeto5514', 'Hogar', 304.9, 38, 'Proveedor2', '2023-10-23', 'Almacén A')
# (5515, 'Artículo5515', 'Hogar', 489.61, 40, 'Proveedor3', '2023-09-13', 'Almacén C')
# (5516, 'Objeto5516', 'Electrónica', 88.26, 2, 'Proveedor2', '2023-04-08', 'Almacén C')
# (5517, 'Artículo5517', 'Electrónica', 158.79, 12, 'Proveedor1', '2023-10-26', 'Almacén A')
# (5518, 'Artículo5518', 'Jardín', 468.01, 97, 'Proveedor3', '2023-03-14', 'Almacén B')
# (5519, 'Artículo5519', 'Jardín', 146.15, 18, 'Proveedor3', '2023-01-26', 'Almacén A')
# (5520, 'Producto5520', 'Hogar', 50.36, 6, 'Proveedor3', '2023-08-12', 'Almacén C')
# (5521, 'Objeto5521', 'Deportes', 20.74, 97, 'Proveedor1', '2023-12-23', 'Almacén C')
# (5522, 'Objeto5522', 'Electrónica', 393.79, 48, 'Proveedor2', '2023-05-26', 'Almacén C')
# (5523, 'Artículo5523', 'Electrónica', 136.63, 56, 'Proveedor3', '2023-10-14', 'Almacén B')
# (5524, 'Producto5524', 'Electrónica', 365.74, 12, 'Proveedor2', '2023-08-12', 'Almacén A')
# (5525, 'Objeto5525', 'Hogar', 244.94, 40, 'Proveedor1', '2023-09-13', 'Almacén C')
# (5526, 'Objeto5526', 'Electrónica', 111.94, 37, 'Proveedor3', '2023-12-28', 'Almacén B')
# (5527, 'Objeto5527', 'Moda', 82.94, 89, 'Proveedor3', '2023-09-14', 'Almacén B')
# (5528, 'Producto5528', 'Hogar', 131.69, 78, 'Proveedor2', '2023-03-12', 'Almacén A')
# (5529, 'Artículo5529', 'Hogar', 19.21, 18, 'Proveedor3', '2023-07-13', 'Almacén A')
# (5530, 'Producto5530', 'Deportes', 242.55, 74, 'Proveedor1', '2023-11-08', 'Almacén C')
# (5531, 'Artículo5531', 'Jardín', 378.66, 98, 'Proveedor1', '2023-04-21', 'Almacén A')
# (5532, 'Producto5532', 'Deportes', 315.41, 77, 'Proveedor2', '2023-09-08', 'Almacén C')
# (5533, 'Producto5533', 'Deportes', 195.02, 45, 'Proveedor3', '2023-09-11', 'Almacén C')
# (5534, 'Artículo5534', 'Moda', 135.18, 83, 'Proveedor1', '2023-12-04', 'Almacén C')
# (5535, 'Producto5535', 'Jardín', 439.34, 79, 'Proveedor1', '2023-04-18', 'Almacén C')
# (5536, 'Objeto5536', 'Electrónica', 142.34, 86, 'Proveedor2', '2023-06-13', 'Almacén A')
# (5537, 'Producto5537', 'Moda', 43.83, 93, 'Proveedor1', '2023-08-16', 'Almacén B')
# (5538, 'Artículo5538', 'Jardín', 100.69, 85, 'Proveedor3', '2023-02-28', 'Almacén C')
# (5539, 'Producto5539', 'Moda', 161.8, 87, 'Proveedor3', '2023-07-25', 'Almacén C')
# (5540, 'Artículo5540', 'Jardín', 129.35, 23, 'Proveedor1', '2023-03-10', 'Almacén C')
# (5541, 'Objeto5541', 'Hogar', 19.92, 91, 'Proveedor2', '2023-12-19', 'Almacén B')
# (5542, 'Artículo5542', 'Hogar', 485.69, 91, 'Proveedor3', '2023-04-08', 'Almacén A')
# (5543, 'Producto5543', 'Hogar', 94.76, 56, 'Proveedor2', '2023-06-24', 'Almacén A')
# (5544, 'Producto5544', 'Deportes', 58.68, 54, 'Proveedor1', '2023-11-07', 'Almacén A')
# (5545, 'Producto5545', 'Deportes', 467.6, 51, 'Proveedor1', '2023-06-08', 'Almacén B')
# (5546, 'Objeto5546', 'Jardín', 498.52, 41, 'Proveedor3', '2023-02-12', 'Almacén A')
# (5547, 'Artículo5547', 'Moda', 403.53, 24, 'Proveedor2', '2023-06-14', 'Almacén A')
# (5548, 'Artículo5548', 'Deportes', 81.07, 83, 'Proveedor1', '2023-01-02', 'Almacén B')
# (5549, 'Artículo5549', 'Jardín', 359.75, 22, 'Proveedor3', '2023-08-05', 'Almacén B')
# (5550, 'Artículo5550', 'Jardín', 157.72, 95, 'Proveedor3', '2023-08-16', 'Almacén B')
# (5551, 'Objeto5551', 'Electrónica', 297.77, 1, 'Proveedor2', '2023-04-23', 'Almacén B')
# (5552, 'Artículo5552', 'Electrónica', 250.32, 19, 'Proveedor2', '2023-02-20', 'Almacén C')
# (5553, 'Artículo5553', 'Hogar', 88.3, 27, 'Proveedor2', '2023-07-14', 'Almacén C')
# (5554, 'Objeto5554', 'Deportes', 405.35, 26, 'Proveedor3', '2023-11-04', 'Almacén B')
# (5555, 'Objeto5555', 'Electrónica', 210.16, 30, 'Proveedor1', '2023-11-20', 'Almacén A')
# (5556, 'Producto5556', 'Electrónica', 417.69, 86, 'Proveedor2', '2023-09-24', 'Almacén A')
# (5557, 'Producto5557', 'Hogar', 197.87, 34, 'Proveedor2', '2023-03-17', 'Almacén A')
# (5558, 'Producto5558', 'Electrónica', 272.44, 22, 'Proveedor3', '2023-04-09', 'Almacén B')
# ...
# (9815, 'Objeto9815', 'Hogar', 136.47, 92, 'Proveedor3', '2023-05-12', 'Almacén A')
# (9816, 'Objeto9816', 'Moda', 289.83, 95, 'Proveedor3', '2023-03-04', 'Almacén B')
# (9817, 'Producto9817', 'Electrónica', 211, 65, 'Proveedor3', '2023-11-08', 'Almacén B')
# (9818, 'Artículo9818', 'Hogar', 341.85, 63, 'Proveedor3', '2023-07-25', 'Almacén C')
# (9819, 'Objeto9819', 'Jardín', 355.29, 36, 'Proveedor3', '2023-09-12', 'Almacén C')
# (9820, 'Artículo9820', 'Electrónica', 192.12, 52, 'Proveedor1', '2023-12-10', 'Almacén A')
# (9821, 'Objeto9821', 'Electrónica', 266.83, 14, 'Proveedor1', '2023-05-21', 'Almacén B')
# (9822, 'Objeto9822', 'Hogar', 168.67, 22, 'Proveedor1', '2023-10-08', 'Almacén C')
# (9823, 'Artículo9823', 'Hogar', 297.37, 24, 'Proveedor3', '2023-10-14', 'Almacén A')
# (9824, 'Artículo9824', 'Hogar', 57.86, 29, 'Proveedor1', '2023-02-02', 'Almacén A')
# (9825, 'Objeto9825', 'Deportes', 314.14, 78, 'Proveedor2', '2023-03-21', 'Almacén B')
# (9826, 'Producto9826', 'Electrónica', 74.4, 18, 'Proveedor3', '2023-05-28', 'Almacén C')
# (9827, 'Artículo9827', 'Jardín', 81.78, 70, 'Proveedor2', '2023-12-24', 'Almacén A')
# (9828, 'Producto9828', 'Hogar', 49.44, 60, 'Proveedor1', '2023-10-20', 'Almacén A')
# (9829, 'Objeto9829', 'Moda', 294.72, 53, 'Proveedor3', '2023-02-11', 'Almacén A')
# (9830, 'Producto9830', 'Jardín', 399.14, 95, 'Proveedor3', '2023-08-18', 'Almacén C')
# (9831, 'Objeto9831', 'Jardín', 230.63, 21, 'Proveedor2', '2023-03-28', 'Almacén C')
# (9832, 'Artículo9832', 'Hogar', 304.9, 45, 'Proveedor2', '2023-07-07', 'Almacén A')
# (9833, 'Producto9833', 'Hogar', 152.87, 40, 'Proveedor2', '2023-01-14', 'Almacén C')
# (9834, 'Artículo9834', 'Hogar', 366.75, 68, 'Proveedor3', '2023-01-14', 'Almacén C')
# (9835, 'Objeto9835', 'Jardín', 272.85, 14, 'Proveedor3', '2023-12-14', 'Almacén B')
# (9836, 'Producto9836', 'Electrónica', 178.29, 85, 'Proveedor3', '2023-08-22', 'Almacén A')
# (9837, 'Objeto9837', 'Hogar', 393.95, 94, 'Proveedor2', '2023-08-08', 'Almacén A')
# (9838, 'Artículo9838', 'Moda', 412.51, 92, 'Proveedor3', '2023-03-23', 'Almacén B')
# (9839, 'Artículo9839', 'Deportes', 170.75, 1, 'Proveedor1', '2023-04-16', 'Almacén A')
# (9840, 'Artículo9840', 'Moda', 400.26, 86, 'Proveedor2', '2023-08-24', 'Almacén A')
# (9841, 'Artículo9841', 'Electrónica', 245.5, 22, 'Proveedor2', '2023-11-05', 'Almacén A')
# (9842, 'Producto9842', 'Moda', 162.61, 9, 'Proveedor1', '2023-05-10', 'Almacén A')
# (9843, 'Artículo9843', 'Deportes', 383.03, 56, 'Proveedor2', '2023-04-05', 'Almacén C')
# (9844, 'Objeto9844', 'Deportes', 289.22, 64, 'Proveedor2', '2023-12-18', 'Almacén C')
# (9845, 'Objeto9845', 'Hogar', 166, 71, 'Proveedor3', '2023-11-07', 'Almacén B')
# (9846, 'Producto9846', 'Hogar', 432.91, 56, 'Proveedor1', '2023-12-13', 'Almacén C')
# (9847, 'Objeto9847', 'Hogar', 438.22, 22, 'Proveedor1', '2023-09-15', 'Almacén A')
# (9848, 'Artículo9848', 'Deportes', 255.18, 23, 'Proveedor2', '2023-06-03', 'Almacén C')
# (9849, 'Objeto9849', 'Moda', 282.74, 19, 'Proveedor2', '2023-03-26', 'Almacén A')
# (9850, 'Artículo9850', 'Electrónica', 321.11, 86, 'Proveedor2', '2023-07-07', 'Almacén B')
# (9851, 'Objeto9851', 'Electrónica', 167.65, 46, 'Proveedor2', '2023-09-04', 'Almacén A')
# (9852, 'Artículo9852', 'Jardín', 51.79, 100, 'Proveedor3', '2023-12-09', 'Almacén C')
# (9853, 'Objeto9853', 'Deportes', 405.97, 48, 'Proveedor2', '2023-05-13', 'Almacén B')
# (9854, 'Artículo9854', 'Moda', 336.62, 23, 'Proveedor1', '2023-12-10', 'Almacén A')
# (9855, 'Artículo9855', 'Jardín', 130.6, 91, 'Proveedor3', '2023-11-04', 'Almacén B')
# (9856, 'Objeto9856', 'Moda', 482.33, 45, 'Proveedor3', '2023-03-21', 'Almacén C')
# (9857, 'Producto9857', 'Deportes', 296.62, 40, 'Proveedor1', '2023-01-04', 'Almacén A')
# (9858, 'Producto9858', 'Hogar', 121.04, 38, 'Proveedor1', '2023-04-10', 'Almacén A')
# (9859, 'Artículo9859', 'Jardín', 320.51, 2, 'Proveedor3', '2023-07-05', 'Almacén A')
# (9860, 'Producto9860', 'Electrónica', 407.02, 54, 'Proveedor3', '2023-12-12', 'Almacén B')
# (9861, 'Objeto9861', 'Moda', 399.09, 21, 'Proveedor3', '2023-06-06', 'Almacén B')
# (9862, 'Producto9862', 'Electrónica', 289.66, 51, 'Proveedor2', '2023-02-18', 'Almacén B')
# (9863, 'Producto9863', 'Moda', 181.24, 52, 'Proveedor3', '2023-12-06', 'Almacén A')
# (9864, 'Producto9864', 'Hogar', 470.62, 93, 'Proveedor1', '2023-03-27', 'Almacén B')
# (9865, 'Artículo9865', 'Moda', 301.39, 31, 'Proveedor3', '2023-12-18', 'Almacén B')
# (9866, 'Producto9866', 'Deportes', 368.98, 92, 'Proveedor2', '2023-07-16', 'Almacén C')
# (9867, 'Artículo9867', 'Electrónica', 403.63, 75, 'Proveedor2', '2023-11-10', 'Almacén C')
# (9868, 'Artículo9868', 'Moda', 133.8, 26, 'Proveedor2', '2023-10-04', 'Almacén A')
# (9869, 'Objeto9869', 'Electrónica', 306.07, 32, 'Proveedor2', '2023-08-11', 'Almacén A')
# (9870, 'Producto9870', 'Deportes', 102.44, 19, 'Proveedor2', '2023-11-03', 'Almacén A')
# (9871, 'Artículo9871', 'Electrónica', 172.87, 57, 'Proveedor2', '2023-04-15', 'Almacén A')
# (9872, 'Artículo9872', 'Electrónica', 362.16, 68, 'Proveedor2', '2023-10-25', 'Almacén C')
# (9873, 'Producto9873', 'Hogar', 186.36, 72, 'Proveedor3', '2023-09-14', 'Almacén C')
# (9874, 'Objeto9874', 'Jardín', 170.98, 59, 'Proveedor3', '2023-09-25', 'Almacén C')
# (9875, 'Producto9875', 'Moda', 418.98, 69, 'Proveedor3', '2023-10-24', 'Almacén A')
# (9876, 'Artículo9876', 'Moda', 234.95, 82, 'Proveedor2', '2023-10-07', 'Almacén A')
# (9877, 'Artículo9877', 'Deportes', 176.64, 80, 'Proveedor1', '2023-08-17', 'Almacén A')
# (9878, 'Artículo9878', 'Electrónica', 464.19, 52, 'Proveedor1', '2023-09-16', 'Almacén A')
# (9879, 'Objeto9879', 'Jardín', 370.32, 39, 'Proveedor1', '2023-08-25', 'Almacén C')
# (9880, 'Artículo9880', 'Electrónica', 297.42, 13, 'Proveedor1', '2023-06-07', 'Almacén A')
# (9881, 'Objeto9881', 'Deportes', 355.2, 66, 'Proveedor3', '2023-04-07', 'Almacén B')
# (9882, 'Producto9882', 'Jardín', 147.38, 47, 'Proveedor2', '2023-12-21', 'Almacén C')
# (9883, 'Artículo9883', 'Electrónica', 416.84, 98, 'Proveedor2', '2023-06-21', 'Almacén C')
# (9884, 'Producto9884', 'Jardín', 302.19, 77, 'Proveedor2', '2023-09-08', 'Almacén A')
# (9885, 'Objeto9885', 'Jardín', 322.61, 67, 'Proveedor3', '2023-02-16', 'Almacén B')
# (9886, 'Artículo9886', 'Moda', 477.96, 97, 'Proveedor3', '2023-05-24', 'Almacén A')
# (9887, 'Producto9887', 'Hogar', 459.86, 74, 'Proveedor2', '2023-04-11', 'Almacén C')
# (9888, 'Artículo9888', 'Moda', 421.75, 64, 'Proveedor2', '2023-11-24', 'Almacén A')
# (9889, 'Objeto9889', 'Electrónica', 282.87, 15, 'Proveedor3', '2023-07-14', 'Almacén B')
# (9890, 'Producto9890', 'Electrónica', 15.66, 7, 'Proveedor2', '2023-10-06', 'Almacén B')
# (9891, 'Objeto9891', 'Hogar', 420.37, 75, 'Proveedor1', '2023-08-28', 'Almacén B')
# (9892, 'Objeto9892', 'Hogar', 312.03, 51, 'Proveedor3', '2023-02-10', 'Almacén A')
# (9893, 'Artículo9893', 'Electrónica', 444.52, 65, 'Proveedor1', '2023-01-16', 'Almacén C')
# (9894, 'Producto9894', 'Deportes', 150.96, 71, 'Proveedor1', '2023-04-27', 'Almacén C')
# (9895, 'Artículo9895', 'Moda', 390.37, 42, 'Proveedor2', '2023-08-21', 'Almacén C')
# (9896, 'Objeto9896', 'Jardín', 11, 29, 'Proveedor1', '2023-02-11', 'Almacén C')
# (9897, 'Artículo9897', 'Moda', 223.14, 100, 'Proveedor2', '2023-03-11', 'Almacén B')
# (9898, 'Producto9898', 'Hogar', 353.15, 15, 'Proveedor3', '2023-11-03', 'Almacén B')
# (9899, 'Producto9899', 'Moda', 116.56, 55, 'Proveedor1', '2023-06-11', 'Almacén A')
# (9900, 'Objeto9900', 'Moda', 116.47, 2, 'Proveedor2', '2023-08-16', 'Almacén C')
# (9901, 'Artículo9901', 'Moda', 17.82, 38, 'Proveedor3', '2023-11-11', 'Almacén B')
# (9902, 'Artículo9902', 'Hogar', 357.72, 6, 'Proveedor1', '2023-08-02', 'Almacén C')
# (9903, 'Artículo9903', 'Electrónica', 241.02, 80, 'Proveedor1', '2023-11-03', 'Almacén A')
# (9904, 'Artículo9904', 'Hogar', 107.67, 73, 'Proveedor1', '2023-08-12', 'Almacén B')
# (9905, 'Artículo9905', 'Deportes', 158.19, 94, 'Proveedor3', '2023-02-05', 'Almacén A')
# (9906, 'Artículo9906', 'Jardín', 379.63, 38, 'Proveedor3', '2023-06-08', 'Almacén A')
# (9907, 'Objeto9907', 'Jardín', 432.84, 100, 'Proveedor2', '2023-09-23', 'Almacén C')
# (9908, 'Artículo9908', 'Deportes', 184.58, 89, 'Proveedor2', '2023-04-26', 'Almacén C')
# (9909, 'Artículo9909', 'Moda', 145.62, 20, 'Proveedor1', '2023-04-05', 'Almacén A')
# (9910, 'Objeto9910', 'Electrónica', 414.44, 27, 'Proveedor1', '2023-09-24', 'Almacén B')
# (9911, 'Objeto9911', 'Electrónica', 438.75, 64, 'Proveedor2', '2023-08-07', 'Almacén B')
# (9912, 'Artículo9912', 'Electrónica', 257.13, 75, 'Proveedor3', '2023-03-15', 'Almacén A')
# (9913, 'Objeto9913', 'Jardín', 277.93, 12, 'Proveedor3', '2023-10-05', 'Almacén C')
# (9914, 'Producto9914', 'Moda', 139.79, 56, 'Proveedor2', '2023-09-08', 'Almacén B')
# (9915, 'Objeto9915', 'Jardín', 366.9, 40, 'Proveedor1', '2023-05-09', 'Almacén B')
# (9916, 'Objeto9916', 'Deportes', 329.84, 84, 'Proveedor2', '2023-12-01', 'Almacén B')
# (9917, 'Artículo9917', 'Jardín', 149.07, 30, 'Proveedor3', '2023-07-13', 'Almacén C')
# (9918, 'Producto9918', 'Jardín', 302.63, 81, 'Proveedor3', '2023-11-24', 'Almacén C')
# (9919, 'Artículo9919', 'Hogar', 449.95, 76, 'Proveedor2', '2023-12-08', 'Almacén C')
# (9920, 'Artículo9920', 'Electrónica', 28.45, 93, 'Proveedor3', '2023-08-25', 'Almacén A')
# (9921, 'Objeto9921', 'Deportes', 338.82, 46, 'Proveedor3', '2023-08-24', 'Almacén C')
# (9922, 'Objeto9922', 'Jardín', 188.54, 77, 'Proveedor3', '2023-04-16', 'Almacén C')
# (9923, 'Artículo9923', 'Deportes', 485.18, 8, 'Proveedor2', '2023-05-07', 'Almacén A')
# (9924, 'Artículo9924', 'Moda', 199.53, 95, 'Proveedor3', '2023-03-04', 'Almacén B')
# (9925, 'Producto9925', 'Deportes', 361.95, 20, 'Proveedor2', '2023-02-11', 'Almacén B')
# (9926, 'Producto9926', 'Hogar', 196.13, 16, 'Proveedor3', '2023-03-12', 'Almacén B')
# (9927, 'Objeto9927', 'Deportes', 480.96, 99, 'Proveedor2', '2023-07-10', 'Almacén C')
# (9928, 'Producto9928', 'Electrónica', 29.02, 40, 'Proveedor2', '2023-05-11', 'Almacén B')
# (9929, 'Objeto9929', 'Deportes', 305.92, 87, 'Proveedor2', '2023-09-14', 'Almacén A')
# (9930, 'Objeto9930', 'Moda', 117.61, 72, 'Proveedor1', '2023-02-21', 'Almacén B')
# (9931, 'Producto9931', 'Moda', 16.35, 53, 'Proveedor2', '2023-11-20', 'Almacén C')
# (9932, 'Artículo9932', 'Moda', 63.1, 60, 'Proveedor3', '2023-06-14', 'Almacén B')
# (9933, 'Artículo9933', 'Hogar', 20.88, 38, 'Proveedor2', '2023-05-10', 'Almacén A')
# (9934, 'Artículo9934', 'Hogar', 24.15, 59, 'Proveedor1', '2023-10-22', 'Almacén B')
# (9935, 'Producto9935', 'Moda', 41.09, 75, 'Proveedor1', '2023-02-10', 'Almacén C')
# (9936, 'Artículo9936', 'Jardín', 206.1, 52, 'Proveedor2', '2023-04-26', 'Almacén A')
# (9937, 'Artículo9937', 'Electrónica', 136.53, 72, 'Proveedor3', '2023-10-22', 'Almacén C')
# (9938, 'Producto9938', 'Hogar', 193.27, 66, 'Proveedor3', '2023-02-26', 'Almacén A')
# (9939, 'Producto9939', 'Jardín', 155.46, 16, 'Proveedor1', '2023-02-15', 'Almacén B')
# (9940, 'Artículo9940', 'Hogar', 184.98, 91, 'Proveedor2', '2023-03-16', 'Almacén B')
# (9941, 'Artículo9941', 'Hogar', 168.78, 38, 'Proveedor1', '2023-04-01', 'Almacén C')
# (9942, 'Objeto9942', 'Electrónica', 441.41, 74, 'Proveedor1', '2023-11-14', 'Almacén B')
# (9943, 'Objeto9943', 'Moda', 88.81, 34, 'Proveedor1', '2023-03-16', 'Almacén C')
# (9944, 'Artículo9944', 'Deportes', 234.32, 88, 'Proveedor1', '2023-03-26', 'Almacén B')
# (9945, 'Artículo9945', 'Jardín', 72.39, 56, 'Proveedor3', '2023-06-09', 'Almacén A')
# (9946, 'Artículo9946', 'Jardín', 74.54, 96, 'Proveedor3', '2023-12-10', 'Almacén B')
# (9947, 'Objeto9947', 'Jardín', 16.5, 27, 'Proveedor3', '2023-11-28', 'Almacén A')
# (9948, 'Objeto9948', 'Moda', 345.81, 62, 'Proveedor2', '2023-10-03', 'Almacén C')
# (9949, 'Artículo9949', 'Hogar', 372.31, 11, 'Proveedor3', '2023-02-06', 'Almacén B')
# (9950, 'Producto9950', 'Moda', 497.74, 66, 'Proveedor1', '2023-02-02', 'Almacén C')
# (9951, 'Artículo9951', 'Hogar', 234.81, 98, 'Proveedor3', '2023-11-24', 'Almacén C')
# (9952, 'Artículo9952', 'Electrónica', 353.9, 46, 'Proveedor1', '2023-01-23', 'Almacén A')
# (9953, 'Objeto9953', 'Jardín', 18.56, 55, 'Proveedor1', '2023-12-11', 'Almacén A')
# (9954, 'Producto9954', 'Deportes', 220.54, 65, 'Proveedor1', '2023-11-20', 'Almacén A')
# (9955, 'Objeto9955', 'Hogar', 373.09, 66, 'Proveedor2', '2023-02-21', 'Almacén C')
# (9956, 'Artículo9956', 'Jardín', 377.43, 16, 'Proveedor2', '2023-05-07', 'Almacén B')
# (9957, 'Producto9957', 'Moda', 92.57, 87, 'Proveedor3', '2023-04-01', 'Almacén A')
# (9958, 'Objeto9958', 'Deportes', 13.98, 74, 'Proveedor2', '2023-02-02', 'Almacén C')
# (9959, 'Producto9959', 'Moda', 396.66, 84, 'Proveedor1', '2023-11-10', 'Almacén B')
# (9960, 'Producto9960', 'Hogar', 447.51, 32, 'Proveedor2', '2023-08-26', 'Almacén A')
# (9961, 'Producto9961', 'Jardín', 184.52, 58, 'Proveedor2', '2023-05-27', 'Almacén B')
# (9962, 'Objeto9962', 'Hogar', 488.91, 100, 'Proveedor3', '2023-09-08', 'Almacén C')
# (9963, 'Artículo9963', 'Jardín', 308.66, 86, 'Proveedor1', '2023-02-23', 'Almacén B')
# (9964, 'Producto9964', 'Jardín', 400.58, 24, 'Proveedor1', '2023-03-19', 'Almacén B')
# (9965, 'Objeto9965', 'Deportes', 108.41, 14, 'Proveedor2', '2023-08-21', 'Almacén A')
# (9966, 'Producto9966', 'Deportes', 238.09, 18, 'Proveedor2', '2023-12-20', 'Almacén B')
# (9967, 'Objeto9967', 'Jardín', 374.91, 48, 'Proveedor3', '2023-06-07', 'Almacén A')
# (9968, 'Artículo9968', 'Electrónica', 246.36, 80, 'Proveedor1', '2023-04-14', 'Almacén C')
# (9969, 'Artículo9969', 'Jardín', 22.23, 98, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9970, 'Producto9970', 'Moda', 29.23, 65, 'Proveedor2', '2023-02-24', 'Almacén C')
# (9971, 'Producto9971', 'Jardín', 88.65, 17, 'Proveedor3', '2023-02-08', 'Almacén B')
# (9972, 'Producto9972', 'Moda', 441.74, 87, 'Proveedor1', '2023-07-09', 'Almacén C')
# (9973, 'Artículo9973', 'Hogar', 452.85, 64, 'Proveedor2', '2023-04-17', 'Almacén A')
# (9974, 'Objeto9974', 'Moda', 74.06, 81, 'Proveedor2', '2023-10-28', 'Almacén A')
# (9975, 'Objeto9975', 'Moda', 269.78, 35, 'Proveedor3', '2023-01-16', 'Almacén B')
# (9976, 'Producto9976', 'Hogar', 131.54, 94, 'Proveedor3', '2023-02-03', 'Almacén B')
# (9977, 'Objeto9977', 'Deportes', 178.11, 58, 'Proveedor3', '2023-08-11', 'Almacén C')
# (9978, 'Producto9978', 'Electrónica', 24.05, 17, 'Proveedor3', '2023-02-08', 'Almacén B')
# (9979, 'Artículo9979', 'Moda', 110.88, 45, 'Proveedor3', '2023-08-22', 'Almacén A')
# (9980, 'Producto9980', 'Jardín', 77.59, 72, 'Proveedor2', '2023-05-24', 'Almacén C')
# (9981, 'Objeto9981', 'Deportes', 153.5, 60, 'Proveedor1', '2023-02-13', 'Almacén B')
# (9982, 'Artículo9982', 'Jardín', 327.72, 57, 'Proveedor3', '2023-09-25', 'Almacén A')
# (9983, 'Producto9983', 'Hogar', 350.09, 77, 'Proveedor3', '2023-04-24', 'Almacén A')
# (9984, 'Artículo9984', 'Electrónica', 210.25, 66, 'Proveedor1', '2023-04-11', 'Almacén B')
# (9985, 'Objeto9985', 'Moda', 16.53, 57, 'Proveedor1', '2023-03-27', 'Almacén A')
# (9986, 'Objeto9986', 'Electrónica', 309.31, 25, 'Proveedor1', '2023-06-28', 'Almacén B')
# (9987, 'Objeto9987', 'Electrónica', 184.18, 98, 'Proveedor3', '2023-01-24', 'Almacén A')
# (9988, 'Artículo9988', 'Deportes', 281.51, 66, 'Proveedor2', '2023-06-18', 'Almacén C')
# (9989, 'Producto9989', 'Moda', 21.77, 81, 'Proveedor1', '2023-07-18', 'Almacén B')
# (9990, 'Objeto9990', 'Electrónica', 147.68, 17, 'Proveedor1', '2023-10-04', 'Almacén B')
# (9991, 'Producto9991', 'Jardín', 54.6, 72, 'Proveedor2', '2023-02-26', 'Almacén C')
# (9992, 'Objeto9992', 'Electrónica', 202.44, 16, 'Proveedor2', '2023-08-13', 'Almacén A')
# (9993, 'Objeto9993', 'Electrónica', 455.71, 15, 'Proveedor1', '2023-10-26', 'Almacén A')
# (9994, 'Producto9994', 'Hogar', 61.78, 52, 'Proveedor3', '2023-08-12', 'Almacén B')
# (9995, 'Producto9995', 'Moda', 126.35, 68, 'Proveedor2', '2023-09-07', 'Almacén B')
# (9996, 'Producto9996', 'Jardín', 469.64, 31, 'Proveedor2', '2023-07-20', 'Almacén B')
# (9997, 'Objeto9997', 'Hogar', 130.55, 55, 'Proveedor2', '2023-10-18', 'Almacén A')
# (9998, 'Producto9998', 'Electrónica', 417.55, 17, 'Proveedor2', '2023-11-14', 'Almacén B')
# (9999, 'Artículo9999', 'Jardín', 367.58, 55, 'Proveedor1', '2023-07-03', 'Almacén C')
# (10000, 'Producto10000', 'Hogar', 109.87, 63, 'Proveedor2', '2023-06-25', 'Almacén A')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#        id        nombre    categoria  precio  cantidad   proveedor  \
# 0       9       Objeto9        Hogar  478.27        52  Proveedor2
# 1      53      Objeto53         Moda  471.42        18  Proveedor1
# 2      59      Objeto59         Moda  484.96        75  Proveedor1
# 3      64      Objeto64         Moda  454.55        41  Proveedor3
# 4      77      Objeto77        Hogar  462.24        52  Proveedor2
# ..    ...           ...          ...     ...       ...         ...
# 972  9950  Producto9950         Moda  497.74        66  Proveedor1
# 973  9962    Objeto9962        Hogar  488.91       100  Proveedor3
# 974  9973  Artículo9973        Hogar  452.85        64  Proveedor2
# 975  9993    Objeto9993  Electrónica  455.71        15  Proveedor1
# 976  9996  Producto9996       Jardín  469.64        31  Proveedor2
#
#     fecha_ingreso  ubicacion
# 0      2023-06-28  Almacén C
# 1      2023-07-24  Almacén A
# 2      2023-10-26  Almacén A
# 3      2023-05-14  Almacén C
# 4      2023-12-06  Almacén B
# ..            ...        ...
# 972    2023-02-02  Almacén C
# 973    2023-09-08  Almacén C
# 974    2023-04-17  Almacén A
# 975    2023-10-26  Almacén A
# 976    2023-07-20  Almacén B
#
# [977 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id    nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0   9   Objeto9     Hogar  478.27        52  Proveedor2    2023-06-28
# 1  53  Objeto53      Moda  471.42        18  Proveedor1    2023-07-24
# 2  59  Objeto59      Moda  484.96        75  Proveedor1    2023-10-26
# 3  64  Objeto64      Moda  454.55        41  Proveedor3    2023-05-14
# 4  77  Objeto77     Hogar  462.24        52  Proveedor2    2023-12-06
#
#    ubicacion
# 0  Almacén C
# 1  Almacén A
# 2  Almacén A
# 3  Almacén C
# 4  Almacén B

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id        nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0       9       Objeto9     Hogar  478.27        52  Proveedor2    2023-06-28
# 1      59      Objeto59      Moda  484.96        75  Proveedor1    2023-10-26
# 2      64      Objeto64      Moda  454.55        41  Proveedor3    2023-05-14
# 3      77      Objeto77     Hogar  462.24        52  Proveedor2    2023-12-06
# 4     107   Artículo107      Moda  453.15        27  Proveedor3    2023-02-15
# ..    ...           ...       ...     ...       ...         ...           ...
# 740  9927    Objeto9927  Deportes  480.96        99  Proveedor2    2023-07-10
# 741  9950  Producto9950      Moda  497.74        66  Proveedor1    2023-02-02
# 742  9962    Objeto9962     Hogar  488.91       100  Proveedor3    2023-09-08
# 743  9973  Artículo9973     Hogar  452.85        64  Proveedor2    2023-04-17
# 744  9996  Producto9996    Jardín  469.64        31  Proveedor2    2023-07-20
#
#      ubicacion
# 0    Almacén C
# 1    Almacén A
# 2    Almacén C
# 3    Almacén B
# 4    Almacén C
# ..         ...
# 740  Almacén C
# 741  Almacén C
# 742  Almacén C
# 743  Almacén A
# 744  Almacén B
#
# [745 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-01 20:43:46.653749  Almacén B
# 1 2025-03-06 20:43:46.653789  Almacén C
# 2 2024-12-12 20:43:46.653801  Almacén B
# 3 2025-08-09 20:43:46.653811  Almacén A
# 4 2024-11-25 20:43:46.653819  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-01 20:43:46.654  Almacén B
# 1 2025-03-06 20:43:46.654  Almacén C
# 2 2024-12-12 20:43:46.654  Almacén B
# 3 2025-08-09 20:43:46.654  Almacén A
# 4 2024-11-25 20:43:46.654  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)""", (None, row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']))


# # Insersión de datos en la DB
# for index, row in df.iterrows():
#     c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1381542735.py in <cell line: 0>()
#       6
#       7 # Insersión de datos en la DB
# ----> 8 for index, row in df.iterrows():
#       9     c.execute("""
#      10         INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#
# NameError: name 'df' is not defined
